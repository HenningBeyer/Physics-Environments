# %%
# test PPO, SAC for n=1
# repeat for other n new file/same file

# %%
import physics_environments
import numpy as np
from physics_environments import CartPendulumPhysicsConstants, CartPendulumPhysicsEnvironmentParams, CartPendulumPhysicsEnvironment, \
                                 RLCartPendulumEnvironment, RLCartPendulumEnvironmentParams

from jumanji import register, registered_environments
from jumanji.wrappers import VmapWrapper, AutoResetWrapper, VmapAutoResetWrapper
import jumanji

import jax
import jax.numpy as jnp
import time
import os

import lovely_jax as lj
lj.monkey_patch()

# %%
#jax.config.update('jax_debug_nans', False)
#jax.config.update('jax_debug_infs', False)
#jax.config.update("jax_enable_x64", False)
#jax.config.update('jax_disable_jit', True)

# %%
# Possible Parameter Inspirations: https://github.com/vwxyzjn/cleanrl/blob/master/cleanrl/ppo_continuous_action_isaacgym/ppo_continuous_action_isaacgym.py
# Note that minibatches are sampled as permutations, instead of 
# %run /home/hbeyer/RL_Pendulum_Project/Stoix/stoix/systems/ppo/anakin/ff_ppo_continuous.py  \
\
 env=jumanji/cart_2_pendulum\
 env.solved_return_threshold=750.0\
\
 hydra.searchpath=[/home/hbeyer/RL_Pendulum_Project/Stoix/stoix/configs] \
 hydra.verbose=False\
\
 arch.seed=42\
 arch.total_num_envs=2048\
\
 system.rollout_length=16\
 system.critic_lr=0.003\
 system.actor_lr=0.003\
 system.vf_coef=0.5\
 system.ent_coef=0.01\
 system.epochs=4\
 system.num_minibatches=2\
 system.clip_eps=0.1\
\
 network.actor_network.pre_torso.activation=tanh\
 network.critic_network.pre_torso.activation=tanh\
\
 arch.total_timesteps=30_000_000\
 arch.num_eval_episodes=128\
 arch.num_evaluation=100\
\
 logger.use_wandb=False\
 logger.checkpointing.save_model=True\
 logger.kwargs.detailed_logging=True
# Out:
# Using Anakin System!
# Changing the number of updates to 915: If you want to train for a specific number of updates, please set total_timesteps to None!
# Warning: Due to the interaction of various factors such as rollout length, number of evaluations, etc... the actual number of timesteps that will be run is 29491200! This is a difference of 508800 timesteps! To change this, see total_timestep_checker.py in the utils folder.
# {
# │   'logger': {
# │   │   'base_exp_path': 'results',
# │   │   'use_console': True,
# │   │   'use_tb': False,
# │   │   'use_json': False,
# │   │   'use_neptune': False,
# │   │   'use_wandb': False,
# │   │   'kwargs': {
# │   │   │   'project': None,
# │   │   │   'tags': ['stoix'],
# │   │   │   'detailed_logging': True,
# │   │   │   'json_path': None,
# │   │   │   'upload_json_data': False
# │   │   },
# │   │   'checkpointing': {
# │   │   │   'save_model': True,
# │   │   │   'save_args': {
# │   │   │   │   'save_interval_steps': 1,
# │   │   │   │   'max_to_keep': 1,
# │   │   │   │   'keep_period': None,
# │   │   │   │   'checkpoint_uid': None
# │   │   │   },
# │   │   │   'load_model': False,
# │   │   │   'load_args': {'checkpoint_uid': ''}
# │   │   }
# │   },
# │   'arch': {
# │   │   'architecture_name': 'anakin',
# │   │   'seed': 42,
# │   │   'update_batch_size': 1,
# │   │   'total_num_envs': 2048,
# │   │   'total_timesteps': 30000000,
# │   │   'num_updates': 915,
# │   │   'evaluation_greedy': False,
# │   │   'num_eval_episodes': 128,
# │   │   'num_evaluation': 100,
# │   │   'absolute_metric': True,
# │   │   'num_envs': 2048,
# │   │   'num_updates_per_eval': 9,
# │   │   'devices': [CudaDevice(id=0)]
# │   },
# │   'system': {
# │   │   'system_name': 'ff_ppo',
# │   │   'actor_lr': 0.003,
# │   │   'critic_lr': 0.003,
# │   │   'rollout_length': 16,
# │   │   'epochs': 4,
# │   │   'num_minibatches': 2,
# │   │   'gamma': 0.99,
# │   │   'gae_lambda': 0.95,
# │   │   'clip_eps': 0.1,
# │   │   'ent_coef': 0.01,
# │   │   'vf_coef': 0.5,
# │   │   'max_grad_norm': 0.5,
# │   │   'decay_learning_rates': False,
# │   │   'standardize_advantages': True,
# │   │   'kl_penalty_coef': 3.0,
# │   │   'action_dim': 1,
# │   │   'action_minimum': -25.0,
# │   │   'action_maximum': 25.0
# │   },
# │   'network': {
# │   │   'actor_network': {
# │   │   │   'pre_torso': {
# │   │   │   │   '_target_': 'stoix.networks.torso.MLPTorso',
# │   │   │   │   'layer_sizes': [256, 256, 256, 256],
# │   │   │   │   'use_layer_norm': False,
# │   │   │   │   'activation': 'tanh'
# │   │   │   },
# │   │   │   'action_head': {'_target_': 'stoix.networks.heads.NormalAffineTanhDistributionHead'}
# │   │   },
# │   │   'critic_network': {
# │   │   │   'pre_torso': {
# │   │   │   │   '_target_': 'stoix.networks.torso.MLPTorso',
# │   │   │   │   'layer_sizes': [256, 256, 256, 256],
# │   │   │   │   'use_layer_norm': False,
# │   │   │   │   'activation': 'tanh'
# │   │   │   },
# │   │   │   'critic_head': {'_target_': 'stoix.networks.heads.ScalarCriticHead'}
# │   │   }
# │   },
# │   'env': {
# │   │   'env_name': 'jumanji',
# │   │   'observation_attribute': 'agent_inputs_global',
# │   │   'multi_agent': False,
# │   │   'scenario': {'name': 'cart_n_pendulum-v1', 'task_name': 'cart_2_pendulum'},
# │   │   'kwargs': {
# │   │   │   'params': {
# │   │   │   │   'physics_env_params': {
# │   │   │   │   │   'constants': {
# │   │   │   │   │   │   'n': 2,
# │   │   │   │   │   │   'g': 9.81,
# │   │   │   │   │   │   'l': [0.3, 0.3],
# │   │   │   │   │   │   'r': [0.2, 0.2],
# │   │   │   │   │   │   'm': [0.8, 0.8],
# │   │   │   │   │   │   'I': [0.011, 0.011],
# │   │   │   │   │   │   'mu': [0.015, 0.015]
# │   │   │   │   │   },
# │   │   │   │   │   'env_type': 'compound pendulum',
# │   │   │   │   │   'save_after_init': False,
# │   │   │   │   │   'save_filename': 'env2n_compound pendulum_obj.pkl'
# │   │   │   │   },
# │   │   │   │   'training_generator_type': 'DefaultGenerator',
# │   │   │   │   'dt': 0.01,
# │   │   │   │   't_episode': 10.0,
# │   │   │   │   'max_cart_acceleration': 25.0,
# │   │   │   │   'cart_width': 0.25,
# │   │   │   │   'track_width': 1.25,
# │   │   │   │   'reward_exponent': 1.0,
# │   │   │   │   '_init_phyiscs_env_from_file': False,
# │   │   │   │   '_physics_env_init_filename': 'pendulum_obj_filename.pkl',
# │   │   │   │   '_initialize_env_math': False
# │   │   │   }
# │   │   },
# │   │   'eval_metric': 'episode_return',
# │   │   'solved_return_threshold': 750.0
# │   },
# │   'num_devices': 1
# }
# orbax-checkpoint version: 0.10.1
# [thread=MainThread] Failed to get flag value for EXPERIMENTAL_ORBAX_USE_DISTRIBUTED_PROCESS_ID.
# [process=0][thread=MainThread] CheckpointManager init: checkpointers=<orbax.checkpoint._src.checkpointers.pytree_checkpointer.PyTreeCheckpointer object at 0x7f8d35c4ec80>, item_names=None, item_handlers=None, handler_registry=None
# Configured `CheckpointManager` using deprecated legacy API. Please follow the instructions at https://orbax.readthedocs.io/en/latest/api_refactor.html to migrate.
# Deferred registration for item: "default". Adding handler `<orbax.checkpoint._src.handlers.pytree_checkpoint_handler.PyTreeCheckpointHandler object at 0x7f8d35c4ffa0>` for item "default" and save args `<class 'orbax.checkpoint._src.handlers.pytree_checkpoint_handler.PyTreeSaveArgs'>` and restore args `<class 'orbax.checkpoint._src.handlers.pytree_checkpoint_handler.PyTreeRestoreArgs'>` to `_handler_registry`.
# Deferred registration for item: "metrics". Adding handler `<orbax.checkpoint._src.handlers.json_checkpoint_handler.JsonCheckpointHandler object at 0x7f8d35b04670>` for item "metrics" and save args `<class 'orbax.checkpoint._src.handlers.json_checkpoint_handler.JsonSaveArgs'>` and restore args `<class 'orbax.checkpoint._src.handlers.json_checkpoint_handler.JsonRestoreArgs'>` to `_handler_registry`.
# Initialized registry DefaultCheckpointHandlerRegistry({('default', <class 'orbax.checkpoint._src.handlers.pytree_checkpoint_handler.PyTreeSaveArgs'>): <orbax.checkpoint._src.handlers.pytree_checkpoint_handler.PyTreeCheckpointHandler object at 0x7f8d35c4ffa0>, ('default', <class 'orbax.checkpoint._src.handlers.pytree_checkpoint_handler.PyTreeRestoreArgs'>): <orbax.checkpoint._src.handlers.pytree_checkpoint_handler.PyTreeCheckpointHandler object at 0x7f8d35c4ffa0>, ('metrics', <class 'orbax.checkpoint._src.handlers.json_checkpoint_handler.JsonSaveArgs'>): <orbax.checkpoint._src.handlers.json_checkpoint_handler.JsonCheckpointHandler object at 0x7f8d35b04670>, ('metrics', <class 'orbax.checkpoint._src.handlers.json_checkpoint_handler.JsonRestoreArgs'>): <orbax.checkpoint._src.handlers.json_checkpoint_handler.JsonCheckpointHandler object at 0x7f8d35b04670>}).
# Created directory=/home/hbeyer/RL_Pendulum_Project/physics_environments/experiments/n=2/checkpoints/ff_ppo/20241220040717
# [process=0][thread=MainThread] Skipping global process sync, barrier name: CheckpointManager:create_directory
# Found 0 checkpoint steps in /home/hbeyer/RL_Pendulum_Project/physics_environments/experiments/n=2/checkpoints/ff_ppo/20241220040717
# Saving root metadata
# Creating metadata directory
# Writing root metadata
# Wrote Metadata={'format': None, 'custom': {'checkpointer_version': 1.0, 'arch': {'absolute_metric': True, 'architecture_name': 'anakin', 'evaluation_greedy': False, 'num_envs': 2048, 'num_eval_episodes': 128, 'num_evaluation': 100, 'num_updates': 915, 'num_updates_per_eval': 9, 'seed': 42, 'total_num_envs': 2048, 'total_timesteps': 30000000, 'update_batch_size': 1}, 'env': {'env_name': 'jumanji', 'eval_metric': 'episode_return', 'kwargs': {'params': {'_init_phyiscs_env_from_file': False, '_initialize_env_math': False, '_physics_env_init_filename': 'pendulum_obj_filename.pkl', 'cart_width': 0.25, 'dt': 0.01, 'max_cart_acceleration': 25.0, 'physics_env_params': {'constants': {'I': [0.011, 0.011], 'g': 9.81, 'l': [0.3, 0.3], 'm': [0.8, 0.8], 'mu': [0.015, 0.015], 'n': 2, 'r': [0.2, 0.2]}, 'env_type': 'compound pendulum', 'save_after_init': False, 'save_filename': 'env2n_compound pendulum_obj.pkl'}, 'reward_exponent': 1.0, 't_episode': 10.0, 'track_width': 1.25, 'training_generator_type': 'DefaultGenerator'}}, 'multi_agent': False, 'observation_attribute': 'agent_inputs_global', 'scenario': {'name': 'cart_n_pendulum-v1', 'task_name': 'cart_2_pendulum'}, 'solved_return_threshold': 750.0}, 'logger': {'base_exp_path': 'results', 'checkpointing': {'load_args': {'checkpoint_uid': ''}, 'load_model': False, 'save_args': {'checkpoint_uid': None, 'keep_period': None, 'max_to_keep': 1, 'save_interval_steps': 1}, 'save_model': True}, 'kwargs': {'detailed_logging': True, 'json_path': None, 'project': None, 'tags': ['stoix'], 'upload_json_data': False}, 'use_console': True, 'use_json': False, 'use_neptune': False, 'use_tb': False, 'use_wandb': False}, 'network': {'actor_network': {'action_head': {'_target_': 'stoix.networks.heads.NormalAffineTanhDistributionHead'}, 'pre_torso': {'_target_': 'stoix.networks.torso.MLPTorso', 'activation': 'tanh', 'layer_sizes': [256, 256, 256, 256], 'use_layer_norm': False}}, 'critic_network': {'critic_head': {'_target_': 'stoix.networks.heads.ScalarCriticHead'}, 'pre_torso': {'_target_': 'stoix.networks.torso.MLPTorso', 'activation': 'tanh', 'layer_sizes': [256, 256, 256, 256], 'use_layer_norm': False}}}, 'num_devices': 1, 'system': {'action_dim': 1, 'action_maximum': 25.0, 'action_minimum': -25.0, 'actor_lr': 0.003, 'clip_eps': 0.1, 'critic_lr': 0.003, 'decay_learning_rates': False, 'ent_coef': 0.01, 'epochs': 4, 'gae_lambda': 0.95, 'gamma': 0.99, 'kl_penalty_coef': 3.0, 'max_grad_norm': 0.5, 'num_minibatches': 2, 'rollout_length': 16, 'standardize_advantages': True, 'system_name': 'ff_ppo', 'vf_coef': 0.5}}}, json={"format": null, "custom": {"checkpointer_version": 1.0, "arch": {"absolute_metric": true, "architecture_name": "anakin", "evaluation_greedy": false, "num_envs": 2048, "num_eval_episodes": 128, "num_evaluation": 100, "num_updates": 915, "num_updates_per_eval": 9, "seed": 42, "total_num_envs": 2048, "total_timesteps": 30000000, "update_batch_size": 1}, "env": {"env_name": "jumanji", "eval_metric": "episode_return", "kwargs": {"params": {"_init_phyiscs_env_from_file": false, "_initialize_env_math": false, "_physics_env_init_filename": "pendulum_obj_filename.pkl", "cart_width": 0.25, "dt": 0.01, "max_cart_acceleration": 25.0, "physics_env_params": {"constants": {"I": [0.011, 0.011], "g": 9.81, "l": [0.3, 0.3], "m": [0.8, 0.8], "mu": [0.015, 0.015], "n": 2, "r": [0.2, 0.2]}, "env_type": "compound pendulum", "save_after_init": false, "save_filename": "env2n_compound pendulum_obj.pkl"}, "reward_exponent": 1.0, "t_episode": 10.0, "track_width": 1.25, "training_generator_type": "DefaultGenerator"}}, "multi_agent": false, "observation_attribute": "agent_inputs_global", "scenario": {"name": "cart_n_pendulum-v1", "task_name": "cart_2_pendulum"}, "solved_return_threshold": 750.0}, "logger": {"base_exp_path": "results", "checkpointing": {"load_args": {"checkpoint_uid": ""}, "load_model": false, "save_args": {"checkpoint_uid": null, "keep_period": null, "max_to_keep": 1, "save_interval_steps": 1}, "save_model": t ...
# [process=0][thread=MainThread] Skipping global process sync, barrier name: CheckpointManager:save_metadata.0
# [process=0][thread=MainThread] CheckpointManager created,  primary_host=0, CheckpointManagerOptions=CheckpointManagerOptions(save_interval_steps=1, max_to_keep=1, keep_time_interval=None, keep_period=None, should_keep_fn=None, best_fn=<function Checkpointer.__init__.<locals>.<lambda> at 0x7f8d35c23910>, best_mode='max', keep_checkpoints_without_metrics=True, step_prefix=None, step_format_fixed_length=None, step_name_format=None, create=True, cleanup_tmp_directories=False, save_on_steps=frozenset(), single_host_load_and_broadcast=False, todelete_subdir=None, enable_background_delete=False, read_only=False, enable_async_checkpointing=True, async_options=AsyncOptions(timeout_secs=600, barrier_sync_fn=None, post_finalization_callback=None), multiprocessing_options=MultiprocessingOptions(primary_host=0, active_processes=None, barrier_sync_key_prefix=None), should_save_fn=None, file_options=FileOptions(path_permission_mode=None), save_root_metadata=True, temporary_path_class=None), root_directory=/home/hbeyer/RL_Pendulum_Project/physics_environments/experiments/n=2/checkpoints/ff_ppo/20241220040717: <orbax.checkpoint.checkpoint_manager.CheckpointManager object at 0x7f8d35b046d0>
# MISC - Timestep: 294912
# TRAINER - Actor loss: 0.004 | Entropy: 3.863 | Steps per second: 6.455 | Value loss: 0.764
# EVALUATOR - Solve rate: 0.000 | Steps per second: 28535.785 | Episode length mean: 1000.000 | Episode length std: 0.000 | Episode length min: 1000.000 | Episode length max: 1000.000 | Episode return mean: 196.040 | Episode return std: 64.725 | Episode return min: 87.059 | Episode return max: 396.312
# MISC - Timestep: 589824
# TRAINER - Actor loss: 0.001 | Entropy: 3.808 | Steps per second: 73.816 | Value loss: 1.176
# EVALUATOR - Solve rate: 0.000 | Steps per second: 73113.154 | Episode length mean: 1000.000 | Episode length std: 0.000 | Episode length min: 1000.000 | Episode length max: 1000.000 | Episode return mean: 236.427 | Episode return std: 70.773 | Episode return min: 91.606 | Episode return max: 472.972
# MISC - Timestep: 884736
# TRAINER - Actor loss: 0.001 | Entropy: 3.708 | Steps per second: 89.203 | Value loss: 1.788
# EVALUATOR - Solve rate: 0.000 | Steps per second: 74620.219 | Episode length mean: 1000.000 | Episode length std: 0.000 | Episode length min: 1000.000 | Episode length max: 1000.000 | Episode return mean: 272.080 | Episode return std: 51.356 | Episode return min: 144.064 | Episode return max: 411.422
# MISC - Timestep: 1179648
# TRAINER - Actor loss: 0.006 | Entropy: 3.549 | Steps per second: 86.909 | Value loss: 2.622
# EVALUATOR - Solve rate: 0.000 | Steps per second: 72775.432 | Episode length mean: 1000.000 | Episode length std: 0.000 | Episode length min: 1000.000 | Episode length max: 1000.000 | Episode return mean: 402.256 | Episode return std: 66.619 | Episode return min: 260.281 | Episode return max: 508.424
# MISC - Timestep: 1474560
# TRAINER - Actor loss: 0.009 | Entropy: 3.466 | Steps per second: 86.879 | Value loss: 3.378
# EVALUATOR - Solve rate: 0.000 | Steps per second: 73455.402 | Episode length mean: 1000.000 | Episode length std: 0.000 | Episode length min: 1000.000 | Episode length max: 1000.000 | Episode return mean: 411.273 | Episode return std: 66.147 | Episode return min: 271.384 | Episode return max: 520.521
# MISC - Timestep: 1769472
# TRAINER - Actor loss: 0.011 | Entropy: 3.428 | Steps per second: 88.393 | Value loss: 3.012
# EVALUATOR - Solve rate: 0.000 | Steps per second: 80895.683 | Episode length mean: 1000.000 | Episode length std: 0.000 | Episode length min: 1000.000 | Episode length max: 1000.000 | Episode return mean: 431.043 | Episode return std: 58.107 | Episode return min: 280.694 | Episode return max: 509.359
# MISC - Timestep: 2064384
# ACTOR - Steps per second: 387917.861 | Episode length mean: 1000.000 | Episode length std: 0.000 | Episode length min: 1000.000 | Episode length max: 1000.000 | Episode return mean: 283.463 | Episode return std: 53.146 | Episode return min: 134.794 | Episode return max: 453.388
# TRAINER - Actor loss: 0.014 | Entropy: 3.309 | Steps per second: 94.707 | Value loss: 9.783
# EVALUATOR - Solve rate: 0.000 | Steps per second: 82521.294 | Episode length mean: 1000.000 | Episode length std: 0.000 | Episode length min: 1000.000 | Episode length max: 1000.000 | Episode return mean: 442.814 | Episode return std: 53.484 | Episode return min: 284.334 | Episode return max: 521.299
# MISC - Timestep: 2359296
# TRAINER - Actor loss: 0.016 | Entropy: 3.141 | Steps per second: 84.215 | Value loss: 1.368
# EVALUATOR - Solve rate: 0.000 | Steps per second: 68231.823 | Episode length mean: 1000.000 | Episode length std: 0.000 | Episode length min: 1000.000 | Episode length max: 1000.000 | Episode return mean: 465.279 | Episode return std: 39.911 | Episode return min: 318.891 | Episode return max: 506.634
# MISC - Timestep: 2654208
# TRAINER - Actor loss: 0.006 | Entropy: 3.325 | Steps per second: 92.003 | Value loss: 2.506
# EVALUATOR - Solve rate: 0.000 | Steps per second: 80423.942 | Episode length mean: 1000.000 | Episode length std: 0.000 | Episode length min: 1000.000 | Episode length max: 1000.000 | Episode return mean: 479.496 | Episode return std: 23.804 | Episode return min: 354.111 | Episode return max: 519.565
# MISC - Timestep: 2949120
# TRAINER - Actor loss: 0.004 | Entropy: 3.389 | Steps per second: 92.010 | Value loss: 1.945
# EVALUATOR - Solve rate: 0.000 | Steps per second: 78653.508 | Episode length mean: 1000.000 | Episode length std: 0.000 | Episode length min: 1000.000 | Episode length max: 1000.000 | Episode return mean: 478.098 | Episode return std: 31.961 | Episode return min: 345.492 | Episode return max: 518.265
# MISC - Timestep: 3244032
# TRAINER - Actor loss: 0.004 | Entropy: 3.442 | Steps per second: 90.616 | Value loss: 1.371
# EVALUATOR - Solve rate: 0.000 | Steps per second: 64935.859 | Episode length mean: 1000.000 | Episode length std: 0.000 | Episode length min: 1000.000 | Episode length max: 1000.000 | Episode return mean: 481.915 | Episode return std: 24.976 | Episode return min: 369.103 | Episode return max: 517.056
# MISC - Timestep: 3538944
# TRAINER - Actor loss: 0.004 | Entropy: 3.494 | Steps per second: 88.310 | Value loss: 0.915
# EVALUATOR - Solve rate: 0.000 | Steps per second: 71463.920 | Episode length mean: 1000.000 | Episode length std: 0.000 | Episode length min: 1000.000 | Episode length max: 1000.000 | Episode return mean: 486.022 | Episode return std: 24.680 | Episode return min: 385.290 | Episode return max: 524.105
# MISC - Timestep: 3833856
# TRAINER - Actor loss: 0.005 | Entropy: 3.462 | Steps per second: 91.140 | Value loss: 0.621
# EVALUATOR - Solve rate: 0.000 | Steps per second: 74668.707 | Episode length mean: 1000.000 | Episode length std: 0.000 | Episode length min: 1000.000 | Episode length max: 1000.000 | Episode return mean: 485.790 | Episode return std: 32.032 | Episode return min: 370.983 | Episode return max: 521.489
# MISC - Timestep: 4128768
# ACTOR - Steps per second: 374263.155 | Episode length mean: 1000.000 | Episode length std: 0.000 | Episode length min: 1000.000 | Episode length max: 1000.000 | Episode return mean: 462.607 | Episode return std: 31.552 | Episode return min: 309.457 | Episode return max: 523.411
# TRAINER - Actor loss: 0.008 | Entropy: 3.330 | Steps per second: 91.373 | Value loss: 44.581
# EVALUATOR - Solve rate: 0.000 | Steps per second: 66722.159 | Episode length mean: 1000.000 | Episode length std: 0.000 | Episode length min: 1000.000 | Episode length max: 1000.000 | Episode return mean: 481.453 | Episode return std: 29.662 | Episode return min: 366.211 | Episode return max: 523.341
# MISC - Timestep: 4423680
# TRAINER - Actor loss: 0.012 | Entropy: 3.339 | Steps per second: 86.201 | Value loss: 4.814
# EVALUATOR - Solve rate: 0.000 | Steps per second: 68645.950 | Episode length mean: 1000.000 | Episode length std: 0.000 | Episode length min: 1000.000 | Episode length max: 1000.000 | Episode return mean: 471.439 | Episode return std: 29.088 | Episode return min: 337.584 | Episode return max: 517.121
# MISC - Timestep: 4718592
# TRAINER - Actor loss: 0.002 | Entropy: 3.461 | Steps per second: 82.720 | Value loss: 1.443
# EVALUATOR - Solve rate: 0.000 | Steps per second: 69980.697 | Episode length mean: 1000.000 | Episode length std: 0.000 | Episode length min: 1000.000 | Episode length max: 1000.000 | Episode return mean: 465.640 | Episode return std: 38.304 | Episode return min: 333.972 | Episode return max: 519.354
# MISC - Timestep: 5013504
# TRAINER - Actor loss: 0.001 | Entropy: 3.486 | Steps per second: 87.986 | Value loss: 1.037
# EVALUATOR - Solve rate: 0.000 | Steps per second: 86059.623 | Episode length mean: 1000.000 | Episode length std: 0.000 | Episode length min: 1000.000 | Episode length max: 1000.000 | Episode return mean: 483.459 | Episode return std: 21.631 | Episode return min: 355.937 | Episode return max: 514.074
# MISC - Timestep: 5308416
# TRAINER - Actor loss: 0.002 | Entropy: 3.546 | Steps per second: 94.302 | Value loss: 0.751
# EVALUATOR - Solve rate: 0.000 | Steps per second: 76600.379 | Episode length mean: 1000.000 | Episode length std: 0.000 | Episode length min: 1000.000 | Episode length max: 1000.000 | Episode return mean: 489.206 | Episode return std: 22.836 | Episode return min: 392.793 | Episode return max: 528.335
# MISC - Timestep: 5603328
# TRAINER - Actor loss: 0.002 | Entropy: 3.635 | Steps per second: 83.978 | Value loss: 0.501
# EVALUATOR - Solve rate: 0.000 | Steps per second: 76281.668 | Episode length mean: 1000.000 | Episode length std: 0.000 | Episode length min: 1000.000 | Episode length max: 1000.000 | Episode return mean: 493.580 | Episode return std: 21.723 | Episode return min: 371.548 | Episode return max: 538.948
# MISC - Timestep: 5898240
# TRAINER - Actor loss: 0.002 | Entropy: 3.669 | Steps per second: 91.993 | Value loss: 0.357
# EVALUATOR - Solve rate: 0.000 | Steps per second: 77389.431 | Episode length mean: 1000.000 | Episode length std: 0.000 | Episode length min: 1000.000 | Episode length max: 1000.000 | Episode return mean: 503.010 | Episode return std: 15.179 | Episode return min: 420.098 | Episode return max: 539.914
# MISC - Timestep: 6193152
# ACTOR - Steps per second: 375646.500 | Episode length mean: 1000.000 | Episode length std: 0.000 | Episode length min: 1000.000 | Episode length max: 1000.000 | Episode return mean: 466.452 | Episode return std: 29.254 | Episode return min: 314.301 | Episode return max: 539.337
# TRAINER - Actor loss: 0.005 | Entropy: 3.554 | Steps per second: 91.711 | Value loss: 42.165
# EVALUATOR - Solve rate: 0.000 | Steps per second: 75878.063 | Episode length mean: 1000.000 | Episode length std: 0.000 | Episode length min: 1000.000 | Episode length max: 1000.000 | Episode return mean: 496.602 | Episode return std: 15.617 | Episode return min: 420.431 | Episode return max: 529.576
# MISC - Timestep: 6488064
# TRAINER - Actor loss: 0.023 | Entropy: 3.401 | Steps per second: 93.506 | Value loss: 1.235
# EVALUATOR - Solve rate: 0.000 | Steps per second: 79498.331 | Episode length mean: 1000.000 | Episode length std: 0.000 | Episode length min: 1000.000 | Episode length max: 1000.000 | Episode return mean: 489.242 | Episode return std: 20.871 | Episode return min: 394.420 | Episode return max: 528.524
# MISC - Timestep: 6782976
# TRAINER - Actor loss: 0.002 | Entropy: 3.549 | Steps per second: 86.118 | Value loss: 0.565
# EVALUATOR - Solve rate: 0.000 | Steps per second: 68165.636 | Episode length mean: 1000.000 | Episode length std: 0.000 | Episode length min: 1000.000 | Episode length max: 1000.000 | Episode return mean: 493.174 | Episode return std: 18.603 | Episode return min: 411.678 | Episode return max: 525.534
# MISC - Timestep: 7077888
# TRAINER - Actor loss: 0.002 | Entropy: 3.632 | Steps per second: 90.892 | Value loss: 0.366
# EVALUATOR - Solve rate: 0.000 | Steps per second: 65481.246 | Episode length mean: 1000.000 | Episode length std: 0.000 | Episode length min: 1000.000 | Episode length max: 1000.000 | Episode return mean: 495.363 | Episode return std: 25.460 | Episode return min: 396.251 | Episode return max: 571.714
# MISC - Timestep: 7372800
# TRAINER - Actor loss: 0.002 | Entropy: 3.687 | Steps per second: 82.869 | Value loss: 0.229
# EVALUATOR - Solve rate: 0.000 | Steps per second: 70621.359 | Episode length mean: 1000.000 | Episode length std: 0.000 | Episode length min: 1000.000 | Episode length max: 1000.000 | Episode return mean: 506.348 | Episode return std: 26.516 | Episode return min: 404.711 | Episode return max: 552.499
# MISC - Timestep: 7667712
# TRAINER - Actor loss: 0.002 | Entropy: 3.712 | Steps per second: 88.020 | Value loss: 0.174
# EVALUATOR - Solve rate: 0.000 | Steps per second: 77635.725 | Episode length mean: 1000.000 | Episode length std: 0.000 | Episode length min: 1000.000 | Episode length max: 1000.000 | Episode return mean: 515.558 | Episode return std: 30.917 | Episode return min: 394.297 | Episode return max: 548.792
# MISC - Timestep: 7962624
# TRAINER - Actor loss: 0.003 | Entropy: 3.693 | Steps per second: 87.935 | Value loss: 0.142
# EVALUATOR - Solve rate: 0.000 | Steps per second: 66880.875 | Episode length mean: 1000.000 | Episode length std: 0.000 | Episode length min: 1000.000 | Episode length max: 1000.000 | Episode return mean: 526.122 | Episode return std: 28.576 | Episode return min: 373.498 | Episode return max: 559.160
# MISC - Timestep: 8257536
# ACTOR - Steps per second: 355694.862 | Episode length mean: 1000.000 | Episode length std: 0.000 | Episode length min: 1000.000 | Episode length max: 1000.000 | Episode return mean: 495.483 | Episode return std: 17.671 | Episode return min: 376.442 | Episode return max: 559.652
# TRAINER - Actor loss: 0.019 | Entropy: 3.467 | Steps per second: 86.840 | Value loss: 66.992
# EVALUATOR - Solve rate: 0.000 | Steps per second: 77226.801 | Episode length mean: 1000.000 | Episode length std: 0.000 | Episode length min: 1000.000 | Episode length max: 1000.000 | Episode return mean: 499.815 | Episode return std: 23.675 | Episode return min: 385.664 | Episode return max: 551.743
# MISC - Timestep: 8552448
# TRAINER - Actor loss: 0.019 | Entropy: 3.385 | Steps per second: 89.935 | Value loss: 1.498
# EVALUATOR - Solve rate: 0.000 | Steps per second: 79697.456 | Episode length mean: 1000.000 | Episode length std: 0.000 | Episode length min: 1000.000 | Episode length max: 1000.000 | Episode return mean: 490.244 | Episode return std: 26.371 | Episode return min: 390.240 | Episode return max: 536.530
# MISC - Timestep: 8847360
# TRAINER - Actor loss: 0.004 | Entropy: 3.520 | Steps per second: 92.057 | Value loss: 0.661
# EVALUATOR - Solve rate: 0.000 | Steps per second: 78813.125 | Episode length mean: 1000.000 | Episode length std: 0.000 | Episode length min: 1000.000 | Episode length max: 1000.000 | Episode return mean: 494.965 | Episode return std: 25.731 | Episode return min: 352.919 | Episode return max: 521.858
# MISC - Timestep: 9142272
# TRAINER - Actor loss: 0.002 | Entropy: 3.601 | Steps per second: 90.788 | Value loss: 0.362
# EVALUATOR - Solve rate: 0.000 | Steps per second: 77914.426 | Episode length mean: 1000.000 | Episode length std: 0.000 | Episode length min: 1000.000 | Episode length max: 1000.000 | Episode return mean: 511.793 | Episode return std: 29.570 | Episode return min: 374.421 | Episode return max: 543.627
# MISC - Timestep: 9437184
# TRAINER - Actor loss: 0.002 | Entropy: 3.576 | Steps per second: 93.393 | Value loss: 0.304
# EVALUATOR - Solve rate: 0.000 | Steps per second: 78906.036 | Episode length mean: 1000.000 | Episode length std: 0.000 | Episode length min: 1000.000 | Episode length max: 1000.000 | Episode return mean: 511.378 | Episode return std: 30.481 | Episode return min: 410.501 | Episode return max: 547.937
# MISC - Timestep: 9732096
# TRAINER - Actor loss: 0.004 | Entropy: 3.473 | Steps per second: 93.141 | Value loss: 0.222
# EVALUATOR - Solve rate: 0.000 | Steps per second: 80327.965 | Episode length mean: 1000.000 | Episode length std: 0.000 | Episode length min: 1000.000 | Episode length max: 1000.000 | Episode return mean: 510.483 | Episode return std: 36.904 | Episode return min: 390.538 | Episode return max: 552.814
# MISC - Timestep: 10027008
# TRAINER - Actor loss: 0.009 | Entropy: 3.372 | Steps per second: 92.294 | Value loss: 0.173
# EVALUATOR - Solve rate: 0.000 | Steps per second: 69531.768 | Episode length mean: 1000.000 | Episode length std: 0.000 | Episode length min: 1000.000 | Episode length max: 1000.000 | Episode return mean: 522.286 | Episode return std: 41.526 | Episode return min: 368.669 | Episode return max: 559.848
# MISC - Timestep: 10321920
# ACTOR - Steps per second: 344657.109 | Episode length mean: 1000.000 | Episode length std: 0.000 | Episode length min: 1000.000 | Episode length max: 1000.000 | Episode return mean: 513.223 | Episode return std: 29.317 | Episode return min: 367.878 | Episode return max: 554.572
# TRAINER - Actor loss: 0.015 | Entropy: 3.360 | Steps per second: 84.145 | Value loss: 55.569
# EVALUATOR - Solve rate: 0.000 | Steps per second: 64443.706 | Episode length mean: 1000.000 | Episode length std: 0.000 | Episode length min: 1000.000 | Episode length max: 1000.000 | Episode return mean: 528.582 | Episode return std: 33.439 | Episode return min: 403.773 | Episode return max: 566.500
# MISC - Timestep: 10616832
# TRAINER - Actor loss: 0.013 | Entropy: 3.446 | Steps per second: 84.442 | Value loss: 3.055
# EVALUATOR - Solve rate: 0.000 | Steps per second: 71541.542 | Episode length mean: 1000.000 | Episode length std: 0.000 | Episode length min: 1000.000 | Episode length max: 1000.000 | Episode return mean: 510.710 | Episode return std: 26.217 | Episode return min: 408.366 | Episode return max: 538.248
# MISC - Timestep: 10911744
# TRAINER - Actor loss: 0.002 | Entropy: 3.528 | Steps per second: 85.327 | Value loss: 0.575
# EVALUATOR - Solve rate: 0.000 | Steps per second: 75692.316 | Episode length mean: 1000.000 | Episode length std: 0.000 | Episode length min: 1000.000 | Episode length max: 1000.000 | Episode return mean: 514.499 | Episode return std: 23.802 | Episode return min: 386.080 | Episode return max: 540.979
# MISC - Timestep: 11206656
# TRAINER - Actor loss: 0.003 | Entropy: 3.563 | Steps per second: 87.304 | Value loss: 0.435
# EVALUATOR - Solve rate: 0.000 | Steps per second: 67942.940 | Episode length mean: 1000.000 | Episode length std: 0.000 | Episode length min: 1000.000 | Episode length max: 1000.000 | Episode return mean: 512.736 | Episode return std: 25.301 | Episode return min: 387.153 | Episode return max: 548.693
# MISC - Timestep: 11501568
# TRAINER - Actor loss: 0.002 | Entropy: 3.612 | Steps per second: 84.303 | Value loss: 0.355
# EVALUATOR - Solve rate: 0.000 | Steps per second: 72818.479 | Episode length mean: 1000.000 | Episode length std: 0.000 | Episode length min: 1000.000 | Episode length max: 1000.000 | Episode return mean: 518.489 | Episode return std: 27.317 | Episode return min: 353.891 | Episode return max: 544.271
# MISC - Timestep: 11796480
# TRAINER - Actor loss: 0.005 | Entropy: 3.618 | Steps per second: 86.286 | Value loss: 0.248
# EVALUATOR - Solve rate: 0.000 | Steps per second: 68577.503 | Episode length mean: 1000.000 | Episode length std: 0.000 | Episode length min: 1000.000 | Episode length max: 1000.000 | Episode return mean: 513.929 | Episode return std: 20.266 | Episode return min: 396.381 | Episode return max: 536.794
# MISC - Timestep: 12091392
# TRAINER - Actor loss: 0.004 | Entropy: 3.583 | Steps per second: 89.741 | Value loss: 0.171
# EVALUATOR - Solve rate: 0.000 | Steps per second: 80205.811 | Episode length mean: 1000.000 | Episode length std: 0.000 | Episode length min: 1000.000 | Episode length max: 1000.000 | Episode return mean: 521.409 | Episode return std: 18.583 | Episode return min: 430.854 | Episode return max: 549.592
# MISC - Timestep: 12386304
# ACTOR - Steps per second: 379459.931 | Episode length mean: 1000.000 | Episode length std: 0.000 | Episode length min: 1000.000 | Episode length max: 1000.000 | Episode return mean: 513.495 | Episode return std: 29.147 | Episode return min: 371.114 | Episode return max: 555.791
# TRAINER - Actor loss: 0.010 | Entropy: 3.440 | Steps per second: 92.642 | Value loss: 70.281
# EVALUATOR - Solve rate: 0.000 | Steps per second: 79157.122 | Episode length mean: 1000.000 | Episode length std: 0.000 | Episode length min: 1000.000 | Episode length max: 1000.000 | Episode return mean: 501.276 | Episode return std: 14.263 | Episode return min: 415.244 | Episode return max: 533.992
# MISC - Timestep: 12681216
# TRAINER - Actor loss: 0.008 | Entropy: 3.431 | Steps per second: 93.663 | Value loss: 2.313
# EVALUATOR - Solve rate: 0.000 | Steps per second: 80432.593 | Episode length mean: 1000.000 | Episode length std: 0.000 | Episode length min: 1000.000 | Episode length max: 1000.000 | Episode return mean: 489.153 | Episode return std: 23.952 | Episode return min: 373.015 | Episode return max: 531.049
# MISC - Timestep: 12976128
# TRAINER - Actor loss: 0.003 | Entropy: 3.589 | Steps per second: 89.813 | Value loss: 0.432
# EVALUATOR - Solve rate: 0.000 | Steps per second: 87959.974 | Episode length mean: 1000.000 | Episode length std: 0.000 | Episode length min: 1000.000 | Episode length max: 1000.000 | Episode return mean: 500.370 | Episode return std: 23.876 | Episode return min: 394.726 | Episode return max: 526.509
# MISC - Timestep: 13271040
# TRAINER - Actor loss: 0.002 | Entropy: 3.625 | Steps per second: 95.457 | Value loss: 0.296
# EVALUATOR - Solve rate: 0.000 | Steps per second: 89113.832 | Episode length mean: 1000.000 | Episode length std: 0.000 | Episode length min: 1000.000 | Episode length max: 1000.000 | Episode return mean: 507.097 | Episode return std: 14.685 | Episode return min: 403.457 | Episode return max: 538.324
# MISC - Timestep: 13565952
# TRAINER - Actor loss: 0.007 | Entropy: 3.569 | Steps per second: 93.863 | Value loss: 0.229
# EVALUATOR - Solve rate: 0.000 | Steps per second: 73547.467 | Episode length mean: 1000.000 | Episode length std: 0.000 | Episode length min: 1000.000 | Episode length max: 1000.000 | Episode return mean: 502.820 | Episode return std: 23.735 | Episode return min: 412.014 | Episode return max: 540.795
# MISC - Timestep: 13860864
# TRAINER - Actor loss: 0.002 | Entropy: 3.396 | Steps per second: 88.541 | Value loss: 0.143
# EVALUATOR - Solve rate: 0.000 | Steps per second: 67936.062 | Episode length mean: 1000.000 | Episode length std: 0.000 | Episode length min: 1000.000 | Episode length max: 1000.000 | Episode return mean: 506.631 | Episode return std: 25.665 | Episode return min: 420.461 | Episode return max: 549.165
# MISC - Timestep: 14155776
# TRAINER - Actor loss: 0.003 | Entropy: 3.260 | Steps per second: 86.786 | Value loss: 0.107
# EVALUATOR - Solve rate: 0.000 | Steps per second: 66869.480 | Episode length mean: 1000.000 | Episode length std: 0.000 | Episode length min: 1000.000 | Episode length max: 1000.000 | Episode return mean: 511.492 | Episode return std: 28.526 | Episode return min: 401.758 | Episode return max: 556.767
# MISC - Timestep: 14450688
# ACTOR - Steps per second: 341660.642 | Episode length mean: 1000.000 | Episode length std: 0.000 | Episode length min: 1000.000 | Episode length max: 1000.000 | Episode return mean: 508.506 | Episode return std: 17.994 | Episode return min: 393.226 | Episode return max: 545.804
# TRAINER - Actor loss: 0.013 | Entropy: 3.166 | Steps per second: 83.413 | Value loss: 50.714
# EVALUATOR - Solve rate: 0.000 | Steps per second: 72141.180 | Episode length mean: 1000.000 | Episode length std: 0.000 | Episode length min: 1000.000 | Episode length max: 1000.000 | Episode return mean: 493.364 | Episode return std: 40.305 | Episode return min: 350.633 | Episode return max: 552.414
# MISC - Timestep: 14745600
# TRAINER - Actor loss: 0.006 | Entropy: 2.888 | Steps per second: 85.709 | Value loss: 10.576
# EVALUATOR - Solve rate: 0.000 | Steps per second: 65169.335 | Episode length mean: 1000.000 | Episode length std: 0.000 | Episode length min: 1000.000 | Episode length max: 1000.000 | Episode return mean: 468.448 | Episode return std: 53.265 | Episode return min: 344.384 | Episode return max: 540.962
# MISC - Timestep: 15040512
# TRAINER - Actor loss: 0.002 | Entropy: 3.103 | Steps per second: 82.524 | Value loss: 1.065
# EVALUATOR - Solve rate: 0.000 | Steps per second: 69381.705 | Episode length mean: 1000.000 | Episode length std: 0.000 | Episode length min: 1000.000 | Episode length max: 1000.000 | Episode return mean: 487.882 | Episode return std: 42.673 | Episode return min: 364.804 | Episode return max: 553.004
# MISC - Timestep: 15335424
# TRAINER - Actor loss: 0.003 | Entropy: 3.138 | Steps per second: 85.527 | Value loss: 0.889
# EVALUATOR - Solve rate: 0.000 | Steps per second: 71546.052 | Episode length mean: 1000.000 | Episode length std: 0.000 | Episode length min: 1000.000 | Episode length max: 1000.000 | Episode return mean: 502.205 | Episode return std: 36.594 | Episode return min: 368.600 | Episode return max: 555.618
# MISC - Timestep: 15630336
# TRAINER - Actor loss: 0.003 | Entropy: 3.122 | Steps per second: 84.990 | Value loss: 0.724
# EVALUATOR - Solve rate: 0.000 | Steps per second: 78331.084 | Episode length mean: 1000.000 | Episode length std: 0.000 | Episode length min: 1000.000 | Episode length max: 1000.000 | Episode return mean: 505.455 | Episode return std: 32.428 | Episode return min: 381.896 | Episode return max: 552.618
# MISC - Timestep: 15925248
# TRAINER - Actor loss: 0.003 | Entropy: 3.202 | Steps per second: 88.793 | Value loss: 0.586
# EVALUATOR - Solve rate: 0.000 | Steps per second: 79662.712 | Episode length mean: 1000.000 | Episode length std: 0.000 | Episode length min: 1000.000 | Episode length max: 1000.000 | Episode return mean: 524.745 | Episode return std: 24.615 | Episode return min: 419.304 | Episode return max: 566.568
# MISC - Timestep: 16220160
# TRAINER - Actor loss: 0.001 | Entropy: 3.253 | Steps per second: 90.175 | Value loss: 0.356
# EVALUATOR - Solve rate: 0.000 | Steps per second: 80925.155 | Episode length mean: 1000.000 | Episode length std: 0.000 | Episode length min: 1000.000 | Episode length max: 1000.000 | Episode return mean: 522.473 | Episode return std: 23.597 | Episode return min: 424.381 | Episode return max: 557.269
# MISC - Timestep: 16515072
# ACTOR - Steps per second: 379439.677 | Episode length mean: 1000.000 | Episode length std: 0.000 | Episode length min: 1000.000 | Episode length max: 1000.000 | Episode return mean: 500.140 | Episode return std: 35.171 | Episode return min: 351.669 | Episode return max: 569.635
# TRAINER - Actor loss: 0.012 | Entropy: 3.161 | Steps per second: 92.637 | Value loss: 70.931
# EVALUATOR - Solve rate: 0.000 | Steps per second: 76246.275 | Episode length mean: 1000.000 | Episode length std: 0.000 | Episode length min: 1000.000 | Episode length max: 1000.000 | Episode return mean: 507.008 | Episode return std: 36.154 | Episode return min: 389.613 | Episode return max: 556.967
# MISC - Timestep: 16809984
# TRAINER - Actor loss: 0.002 | Entropy: 3.248 | Steps per second: 93.863 | Value loss: 2.175
# EVALUATOR - Solve rate: 0.000 | Steps per second: 79221.120 | Episode length mean: 1000.000 | Episode length std: 0.000 | Episode length min: 1000.000 | Episode length max: 1000.000 | Episode return mean: 503.390 | Episode return std: 35.266 | Episode return min: 365.339 | Episode return max: 552.715
# MISC - Timestep: 17104896
# TRAINER - Actor loss: 0.000 | Entropy: 3.281 | Steps per second: 87.049 | Value loss: 0.832
# EVALUATOR - Solve rate: 0.000 | Steps per second: 80662.564 | Episode length mean: 1000.000 | Episode length std: 0.000 | Episode length min: 1000.000 | Episode length max: 1000.000 | Episode return mean: 499.516 | Episode return std: 36.397 | Episode return min: 383.687 | Episode return max: 568.065
# MISC - Timestep: 17399808
# TRAINER - Actor loss: 0.001 | Entropy: 3.294 | Steps per second: 94.020 | Value loss: 0.519
# EVALUATOR - Solve rate: 0.000 | Steps per second: 79594.128 | Episode length mean: 1000.000 | Episode length std: 0.000 | Episode length min: 1000.000 | Episode length max: 1000.000 | Episode return mean: 522.296 | Episode return std: 37.545 | Episode return min: 403.463 | Episode return max: 579.990
# MISC - Timestep: 17694720
# TRAINER - Actor loss: 0.002 | Entropy: 3.232 | Steps per second: 89.386 | Value loss: 0.365
# EVALUATOR - Solve rate: 0.000 | Steps per second: 75418.079 | Episode length mean: 1000.000 | Episode length std: 0.000 | Episode length min: 1000.000 | Episode length max: 1000.000 | Episode return mean: 511.270 | Episode return std: 40.881 | Episode return min: 399.535 | Episode return max: 570.200
# MISC - Timestep: 17989632
# TRAINER - Actor loss: 0.003 | Entropy: 3.140 | Steps per second: 91.079 | Value loss: 0.278
# EVALUATOR - Solve rate: 0.000 | Steps per second: 82156.355 | Episode length mean: 1000.000 | Episode length std: 0.000 | Episode length min: 1000.000 | Episode length max: 1000.000 | Episode return mean: 519.230 | Episode return std: 38.642 | Episode return min: 394.231 | Episode return max: 567.212
# MISC - Timestep: 18284544
# TRAINER - Actor loss: 0.002 | Entropy: 3.038 | Steps per second: 88.013 | Value loss: 0.213
# EVALUATOR - Solve rate: 0.000 | Steps per second: 70116.210 | Episode length mean: 1000.000 | Episode length std: 0.000 | Episode length min: 1000.000 | Episode length max: 1000.000 | Episode return mean: 529.679 | Episode return std: 34.962 | Episode return min: 365.961 | Episode return max: 584.316
# MISC - Timestep: 18579456
# ACTOR - Steps per second: 353267.089 | Episode length mean: 1000.000 | Episode length std: 0.000 | Episode length min: 1000.000 | Episode length max: 1000.000 | Episode return mean: 527.281 | Episode return std: 31.534 | Episode return min: 365.203 | Episode return max: 592.609
# TRAINER - Actor loss: 0.016 | Entropy: 3.055 | Steps per second: 86.247 | Value loss: 58.647
# EVALUATOR - Solve rate: 0.000 | Steps per second: 70666.805 | Episode length mean: 1000.000 | Episode length std: 0.000 | Episode length min: 1000.000 | Episode length max: 1000.000 | Episode return mean: 508.258 | Episode return std: 48.860 | Episode return min: 367.003 | Episode return max: 577.422
# MISC - Timestep: 18874368
# TRAINER - Actor loss: 0.001 | Entropy: 3.238 | Steps per second: 86.602 | Value loss: 1.405
# EVALUATOR - Solve rate: 0.000 | Steps per second: 77774.116 | Episode length mean: 1000.000 | Episode length std: 0.000 | Episode length min: 1000.000 | Episode length max: 1000.000 | Episode return mean: 498.997 | Episode return std: 41.632 | Episode return min: 377.607 | Episode return max: 573.373
# MISC - Timestep: 19169280
# TRAINER - Actor loss: 0.001 | Entropy: 3.182 | Steps per second: 89.882 | Value loss: 0.948
# EVALUATOR - Solve rate: 0.000 | Steps per second: 78895.531 | Episode length mean: 1000.000 | Episode length std: 0.000 | Episode length min: 1000.000 | Episode length max: 1000.000 | Episode return mean: 512.492 | Episode return std: 36.600 | Episode return min: 401.330 | Episode return max: 566.312
# MISC - Timestep: 19464192
# TRAINER - Actor loss: 0.002 | Entropy: 3.040 | Steps per second: 93.009 | Value loss: 0.750
# EVALUATOR - Solve rate: 0.000 | Steps per second: 77917.785 | Episode length mean: 1000.000 | Episode length std: 0.000 | Episode length min: 1000.000 | Episode length max: 1000.000 | Episode return mean: 527.423 | Episode return std: 38.626 | Episode return min: 399.662 | Episode return max: 581.022
# MISC - Timestep: 19759104
# TRAINER - Actor loss: 0.003 | Entropy: 2.997 | Steps per second: 90.570 | Value loss: 0.548
# EVALUATOR - Solve rate: 0.000 | Steps per second: 78950.792 | Episode length mean: 1000.000 | Episode length std: 0.000 | Episode length min: 1000.000 | Episode length max: 1000.000 | Episode return mean: 530.093 | Episode return std: 39.638 | Episode return min: 406.175 | Episode return max: 586.641
# MISC - Timestep: 20054016
# TRAINER - Actor loss: 0.005 | Entropy: 2.909 | Steps per second: 92.704 | Value loss: 0.368
# EVALUATOR - Solve rate: 0.000 | Steps per second: 78430.824 | Episode length mean: 1000.000 | Episode length std: 0.000 | Episode length min: 1000.000 | Episode length max: 1000.000 | Episode return mean: 529.442 | Episode return std: 33.158 | Episode return min: 430.618 | Episode return max: 582.725
# MISC - Timestep: 20348928
# TRAINER - Actor loss: 0.003 | Entropy: 2.723 | Steps per second: 89.444 | Value loss: 0.245
# EVALUATOR - Solve rate: 0.000 | Steps per second: 80002.580 | Episode length mean: 1000.000 | Episode length std: 0.000 | Episode length min: 1000.000 | Episode length max: 1000.000 | Episode return mean: 549.008 | Episode return std: 17.705 | Episode return min: 479.885 | Episode return max: 579.914
# MISC - Timestep: 20643840
# ACTOR - Steps per second: 385790.666 | Episode length mean: 1000.000 | Episode length std: 0.000 | Episode length min: 1000.000 | Episode length max: 1000.000 | Episode return mean: 518.674 | Episode return std: 35.543 | Episode return min: 378.140 | Episode return max: 580.284
# TRAINER - Actor loss: 0.027 | Entropy: 2.753 | Steps per second: 94.187 | Value loss: 74.910
# EVALUATOR - Solve rate: 0.000 | Steps per second: 77961.199 | Episode length mean: 1000.000 | Episode length std: 0.000 | Episode length min: 1000.000 | Episode length max: 1000.000 | Episode return mean: 482.775 | Episode return std: 34.791 | Episode return min: 369.492 | Episode return max: 539.602
# MISC - Timestep: 20938752
# TRAINER - Actor loss: 0.002 | Entropy: 3.132 | Steps per second: 90.715 | Value loss: 1.327
# EVALUATOR - Solve rate: 0.000 | Steps per second: 70273.803 | Episode length mean: 1000.000 | Episode length std: 0.000 | Episode length min: 1000.000 | Episode length max: 1000.000 | Episode return mean: 480.964 | Episode return std: 43.460 | Episode return min: 346.293 | Episode return max: 555.790
# MISC - Timestep: 21233664
# TRAINER - Actor loss: 0.005 | Entropy: 3.105 | Steps per second: 87.651 | Value loss: 0.961
# EVALUATOR - Solve rate: 0.000 | Steps per second: 69525.708 | Episode length mean: 1000.000 | Episode length std: 0.000 | Episode length min: 1000.000 | Episode length max: 1000.000 | Episode return mean: 497.693 | Episode return std: 32.870 | Episode return min: 380.181 | Episode return max: 553.413
# MISC - Timestep: 21528576
# TRAINER - Actor loss: 0.006 | Entropy: 3.031 | Steps per second: 84.352 | Value loss: 0.969
# EVALUATOR - Solve rate: 0.000 | Steps per second: 73337.851 | Episode length mean: 1000.000 | Episode length std: 0.000 | Episode length min: 1000.000 | Episode length max: 1000.000 | Episode return mean: 508.678 | Episode return std: 29.410 | Episode return min: 403.946 | Episode return max: 552.907
# MISC - Timestep: 21823488
# TRAINER - Actor loss: 0.004 | Entropy: 2.974 | Steps per second: 87.777 | Value loss: 0.741
# EVALUATOR - Solve rate: 0.000 | Steps per second: 74557.172 | Episode length mean: 1000.000 | Episode length std: 0.000 | Episode length min: 1000.000 | Episode length max: 1000.000 | Episode return mean: 514.026 | Episode return std: 36.679 | Episode return min: 404.884 | Episode return max: 577.144
# MISC - Timestep: 22118400
# TRAINER - Actor loss: 0.003 | Entropy: 3.023 | Steps per second: 86.514 | Value loss: 0.477
# EVALUATOR - Solve rate: 0.000 | Steps per second: 67092.083 | Episode length mean: 1000.000 | Episode length std: 0.000 | Episode length min: 1000.000 | Episode length max: 1000.000 | Episode return mean: 513.243 | Episode return std: 35.990 | Episode return min: 403.066 | Episode return max: 573.795
# MISC - Timestep: 22413312
# TRAINER - Actor loss: 0.004 | Entropy: 3.031 | Steps per second: 89.648 | Value loss: 0.381
# EVALUATOR - Solve rate: 0.000 | Steps per second: 76300.022 | Episode length mean: 1000.000 | Episode length std: 0.000 | Episode length min: 1000.000 | Episode length max: 1000.000 | Episode return mean: 521.936 | Episode return std: 39.473 | Episode return min: 413.401 | Episode return max: 584.789
# MISC - Timestep: 22708224
# ACTOR - Steps per second: 376396.467 | Episode length mean: 1000.000 | Episode length std: 0.000 | Episode length min: 1000.000 | Episode length max: 1000.000 | Episode return mean: 504.176 | Episode return std: 34.620 | Episode return min: 386.727 | Episode return max: 602.351
# TRAINER - Actor loss: 0.013 | Entropy: 2.947 | Steps per second: 91.894 | Value loss: 55.169
# EVALUATOR - Solve rate: 0.000 | Steps per second: 78532.174 | Episode length mean: 1000.000 | Episode length std: 0.000 | Episode length min: 1000.000 | Episode length max: 1000.000 | Episode return mean: 505.489 | Episode return std: 31.375 | Episode return min: 425.974 | Episode return max: 559.906
# MISC - Timestep: 23003136
# TRAINER - Actor loss: 0.001 | Entropy: 2.894 | Steps per second: 89.292 | Value loss: 1.153
# EVALUATOR - Solve rate: 0.000 | Steps per second: 76651.376 | Episode length mean: 1000.000 | Episode length std: 0.000 | Episode length min: 1000.000 | Episode length max: 1000.000 | Episode return mean: 520.568 | Episode return std: 25.467 | Episode return min: 372.343 | Episode return max: 559.119
# MISC - Timestep: 23298048
# TRAINER - Actor loss: 0.000 | Entropy: 2.945 | Steps per second: 90.113 | Value loss: 0.915
# EVALUATOR - Solve rate: 0.000 | Steps per second: 82026.601 | Episode length mean: 1000.000 | Episode length std: 0.000 | Episode length min: 1000.000 | Episode length max: 1000.000 | Episode return mean: 519.252 | Episode return std: 24.492 | Episode return min: 415.694 | Episode return max: 559.766
# MISC - Timestep: 23592960
# TRAINER - Actor loss: 0.002 | Entropy: 2.923 | Steps per second: 95.444 | Value loss: 0.681
# EVALUATOR - Solve rate: 0.000 | Steps per second: 75198.324 | Episode length mean: 1000.000 | Episode length std: 0.000 | Episode length min: 1000.000 | Episode length max: 1000.000 | Episode return mean: 535.466 | Episode return std: 23.760 | Episode return min: 436.224 | Episode return max: 579.493
# MISC - Timestep: 23887872
# TRAINER - Actor loss: 0.002 | Entropy: 3.062 | Steps per second: 95.197 | Value loss: 0.441
# EVALUATOR - Solve rate: 0.000 | Steps per second: 79035.324 | Episode length mean: 1000.000 | Episode length std: 0.000 | Episode length min: 1000.000 | Episode length max: 1000.000 | Episode return mean: 549.321 | Episode return std: 29.015 | Episode return min: 454.530 | Episode return max: 612.271
# MISC - Timestep: 24182784
# TRAINER - Actor loss: 0.002 | Entropy: 3.041 | Steps per second: 82.180 | Value loss: 0.405
# EVALUATOR - Solve rate: 0.000 | Steps per second: 76015.915 | Episode length mean: 1000.000 | Episode length std: 0.000 | Episode length min: 1000.000 | Episode length max: 1000.000 | Episode return mean: 553.604 | Episode return std: 36.163 | Episode return min: 426.514 | Episode return max: 608.080
# MISC - Timestep: 24477696
# TRAINER - Actor loss: 0.010 | Entropy: 2.858 | Steps per second: 91.416 | Value loss: 0.467
# EVALUATOR - Solve rate: 0.000 | Steps per second: 73641.217 | Episode length mean: 1000.000 | Episode length std: 0.000 | Episode length min: 1000.000 | Episode length max: 1000.000 | Episode return mean: 549.028 | Episode return std: 38.055 | Episode return min: 415.495 | Episode return max: 605.166
# MISC - Timestep: 24772608
# ACTOR - Steps per second: 355457.622 | Episode length mean: 1000.000 | Episode length std: 0.000 | Episode length min: 1000.000 | Episode length max: 1000.000 | Episode return mean: 525.709 | Episode return std: 32.086 | Episode return min: 393.137 | Episode return max: 599.898
# TRAINER - Actor loss: 0.016 | Entropy: 2.823 | Steps per second: 86.782 | Value loss: 79.705
# EVALUATOR - Solve rate: 0.000 | Steps per second: 66232.214 | Episode length mean: 1000.000 | Episode length std: 0.000 | Episode length min: 1000.000 | Episode length max: 1000.000 | Episode return mean: 548.318 | Episode return std: 39.669 | Episode return min: 443.294 | Episode return max: 611.062
# MISC - Timestep: 25067520
# TRAINER - Actor loss: 0.001 | Entropy: 2.919 | Steps per second: 91.618 | Value loss: 1.351
# EVALUATOR - Solve rate: 0.000 | Steps per second: 72549.064 | Episode length mean: 1000.000 | Episode length std: 0.000 | Episode length min: 1000.000 | Episode length max: 1000.000 | Episode return mean: 536.238 | Episode return std: 44.494 | Episode return min: 385.367 | Episode return max: 596.965
# MISC - Timestep: 25362432
# TRAINER - Actor loss: 0.001 | Entropy: 3.025 | Steps per second: 85.638 | Value loss: 0.774
# EVALUATOR - Solve rate: 0.000 | Steps per second: 76872.101 | Episode length mean: 1000.000 | Episode length std: 0.000 | Episode length min: 1000.000 | Episode length max: 1000.000 | Episode return mean: 544.914 | Episode return std: 43.603 | Episode return min: 401.186 | Episode return max: 619.606
# MISC - Timestep: 25657344
# TRAINER - Actor loss: 0.003 | Entropy: 3.016 | Steps per second: 85.524 | Value loss: 0.562
# EVALUATOR - Solve rate: 0.000 | Steps per second: 73157.090 | Episode length mean: 1000.000 | Episode length std: 0.000 | Episode length min: 1000.000 | Episode length max: 1000.000 | Episode return mean: 562.047 | Episode return std: 36.890 | Episode return min: 420.888 | Episode return max: 606.382
# MISC - Timestep: 25952256
# TRAINER - Actor loss: 0.004 | Entropy: 2.967 | Steps per second: 79.532 | Value loss: 0.391
# EVALUATOR - Solve rate: 0.000 | Steps per second: 70436.237 | Episode length mean: 1000.000 | Episode length std: 0.000 | Episode length min: 1000.000 | Episode length max: 1000.000 | Episode return mean: 568.444 | Episode return std: 38.840 | Episode return min: 432.902 | Episode return max: 641.522
# MISC - Timestep: 26247168
# TRAINER - Actor loss: 0.008 | Entropy: 2.992 | Steps per second: 95.876 | Value loss: 0.369
# EVALUATOR - Solve rate: 0.000 | Steps per second: 81800.574 | Episode length mean: 1000.000 | Episode length std: 0.000 | Episode length min: 1000.000 | Episode length max: 1000.000 | Episode return mean: 570.178 | Episode return std: 39.548 | Episode return min: 412.812 | Episode return max: 632.260
# MISC - Timestep: 26542080
# TRAINER - Actor loss: 0.005 | Entropy: 2.908 | Steps per second: 94.297 | Value loss: 0.503
# EVALUATOR - Solve rate: 0.000 | Steps per second: 81465.004 | Episode length mean: 1000.000 | Episode length std: 0.000 | Episode length min: 1000.000 | Episode length max: 1000.000 | Episode return mean: 561.984 | Episode return std: 41.358 | Episode return min: 440.653 | Episode return max: 636.000
# MISC - Timestep: 26836992
# ACTOR - Steps per second: 390646.402 | Episode length mean: 1000.000 | Episode length std: 0.000 | Episode length min: 1000.000 | Episode length max: 1000.000 | Episode return mean: 562.890 | Episode return std: 38.826 | Episode return min: 399.823 | Episode return max: 631.153
# TRAINER - Actor loss: 0.009 | Entropy: 2.766 | Steps per second: 95.373 | Value loss: 63.538
# EVALUATOR - Solve rate: 0.000 | Steps per second: 77943.576 | Episode length mean: 1000.000 | Episode length std: 0.000 | Episode length min: 1000.000 | Episode length max: 1000.000 | Episode return mean: 544.406 | Episode return std: 44.672 | Episode return min: 393.810 | Episode return max: 630.270
# MISC - Timestep: 27131904
# TRAINER - Actor loss: 0.001 | Entropy: 2.842 | Steps per second: 90.809 | Value loss: 1.690
# EVALUATOR - Solve rate: 0.000 | Steps per second: 78008.085 | Episode length mean: 1000.000 | Episode length std: 0.000 | Episode length min: 1000.000 | Episode length max: 1000.000 | Episode return mean: 547.017 | Episode return std: 38.897 | Episode return min: 420.419 | Episode return max: 609.769
# MISC - Timestep: 27426816
# TRAINER - Actor loss: 0.002 | Entropy: 2.824 | Steps per second: 90.949 | Value loss: 0.758
