# %%
# test PPO, SAC for n=1
# repeat for other n new file/same file

# %%
import physics_environments
import numpy as np
from physics_environments import CartPendulumPhysicsConstants, CartPendulumPhysicsEnvironmentParams, CartPendulumPhysicsEnvironment, \
                                 RLCartPendulumEnvironment, RLCartPendulumEnvironmentParams

from jumanji import register, registered_environments
from jumanji.wrappers import VmapWrapper, AutoResetWrapper, VmapAutoResetWrapper
import jumanji

import jax
import jax.numpy as jnp
import time
import os

# %%
# 3072
# num evaluation: evaluate n times over all total_timesteps

# %%
# %run /home/hbeyer/RL_Pendulum_Project/Stoix/stoix/systems/ppo/anakin/ff_ppo_continuous.py  \
 env=jumanji/cart_1_pendulum\
 hydra.searchpath=[/home/hbeyer/RL_Pendulum_Project/Stoix/stoix/configs] \
 hydra.verbose=False\
 arch.seed=42\
 arch.total_num_envs=5120\
 arch.total_timesteps=1_000_000_000\
 arch.num_eval_episodes=128\
 arch.num_evaluation=100\
 logger.use_wandb=False\
 logger.checkpointing.save_model=True\
 logger.kwargs.detailed_logging=True
# Out:
# Using Anakin System!
# Changing the number of updates to 12207: If you want to train for a specific number of updates, please set total_timesteps to None!
# Warning: Due to the interaction of various factors such as rollout length, number of evaluations, etc... the actual number of timesteps that will be run is 999424000! This is a difference of 576000 timesteps! To change this, see total_timestep_checker.py in the utils folder.
# {
# │   'logger': {
# │   │   'base_exp_path': 'results',
# │   │   'use_console': True,
# │   │   'use_tb': False,
# │   │   'use_json': False,
# │   │   'use_neptune': False,
# │   │   'use_wandb': False,
# │   │   'kwargs': {
# │   │   │   'project': None,
# │   │   │   'tags': ['stoix'],
# │   │   │   'detailed_logging': True,
# │   │   │   'json_path': None,
# │   │   │   'upload_json_data': False
# │   │   },
# │   │   'checkpointing': {
# │   │   │   'save_model': True,
# │   │   │   'save_args': {
# │   │   │   │   'save_interval_steps': 1,
# │   │   │   │   'max_to_keep': 1,
# │   │   │   │   'keep_period': None,
# │   │   │   │   'checkpoint_uid': None
# │   │   │   },
# │   │   │   'load_model': False,
# │   │   │   'load_args': {'checkpoint_uid': ''}
# │   │   }
# │   },
# │   'arch': {
# │   │   'architecture_name': 'anakin',
# │   │   'seed': 42,
# │   │   'update_batch_size': 1,
# │   │   'total_num_envs': 5120,
# │   │   'total_timesteps': 1000000000,
# │   │   'num_updates': 12207,
# │   │   'evaluation_greedy': False,
# │   │   'num_eval_episodes': 128,
# │   │   'num_evaluation': 100,
# │   │   'absolute_metric': True,
# │   │   'num_envs': 5120,
# │   │   'num_updates_per_eval': 122,
# │   │   'devices': [CudaDevice(id=0)]
# │   },
# │   'system': {
# │   │   'system_name': 'ff_ppo',
# │   │   'actor_lr': 0.0003,
# │   │   'critic_lr': 0.0003,
# │   │   'rollout_length': 16,
# │   │   'epochs': 4,
# │   │   'num_minibatches': 16,
# │   │   'gamma': 0.99,
# │   │   'gae_lambda': 0.95,
# │   │   'clip_eps': 0.2,
# │   │   'ent_coef': 0.001,
# │   │   'vf_coef': 1.0,
# │   │   'max_grad_norm': 0.5,
# │   │   'decay_learning_rates': False,
# │   │   'standardize_advantages': True,
# │   │   'kl_penalty_coef': 3.0,
# │   │   'action_dim': 1,
# │   │   'action_minimum': -25.0,
# │   │   'action_maximum': 25.0
# │   },
# │   'network': {
# │   │   'actor_network': {
# │   │   │   'pre_torso': {
# │   │   │   │   '_target_': 'stoix.networks.torso.MLPTorso',
# │   │   │   │   'layer_sizes': [256, 256, 256, 256],
# │   │   │   │   'use_layer_norm': False,
# │   │   │   │   'activation': 'silu'
# │   │   │   },
# │   │   │   'action_head': {'_target_': 'stoix.networks.heads.NormalAffineTanhDistributionHead'}
# │   │   },
# │   │   'critic_network': {
# │   │   │   'pre_torso': {
# │   │   │   │   '_target_': 'stoix.networks.torso.MLPTorso',
# │   │   │   │   'layer_sizes': [256, 256, 256, 256],
# │   │   │   │   'use_layer_norm': False,
# │   │   │   │   'activation': 'silu'
# │   │   │   },
# │   │   │   'critic_head': {'_target_': 'stoix.networks.heads.ScalarCriticHead'}
# │   │   }
# │   },
# │   'env': {
# │   │   'env_name': 'jumanji',
# │   │   'observation_attribute': 'agent_inputs_global',
# │   │   'multi_agent': False,
# │   │   'scenario': {'name': 'cart_n_pendulum-v1', 'task_name': 'cart_1_pendulum'},
# │   │   'kwargs': {
# │   │   │   'params': {
# │   │   │   │   'physics_env_params': {
# │   │   │   │   │   'constants': {
# │   │   │   │   │   │   'n': 1,
# │   │   │   │   │   │   'g': 9.81,
# │   │   │   │   │   │   'l': [0.3],
# │   │   │   │   │   │   'r': [0.2],
# │   │   │   │   │   │   'm': [0.8],
# │   │   │   │   │   │   'I': [0.011],
# │   │   │   │   │   │   'mu': [0.015]
# │   │   │   │   │   },
# │   │   │   │   │   'env_type': 'compound pendulum',
# │   │   │   │   │   'save_after_init': False,
# │   │   │   │   │   'save_filename': 'env1n_compound pendulum_obj.pkl'
# │   │   │   │   },
# │   │   │   │   'training_generator_type': 'DefaultGenerator',
# │   │   │   │   'dt': 0.01,
# │   │   │   │   't_episode': 10.0,
# │   │   │   │   'max_cart_acceleration': 25.0,
# │   │   │   │   'cart_width': 0.25,
# │   │   │   │   'track_width': 1.25,
# │   │   │   │   'reward_exponent': 1.0,
# │   │   │   │   '_init_phyiscs_env_from_file': False,
# │   │   │   │   '_physics_env_init_filename': 'pendulum_obj_filename.pkl',
# │   │   │   │   '_initialize_env_math': False
# │   │   │   }
# │   │   },
# │   │   'eval_metric': 'episode_return',
# │   │   'solved_return_threshold': 500.0
# │   },
# │   'num_devices': 1
# }
# orbax-checkpoint version: 0.10.1
# [thread=MainThread] Failed to get flag value for EXPERIMENTAL_ORBAX_USE_DISTRIBUTED_PROCESS_ID.
# [process=0][thread=MainThread] CheckpointManager init: checkpointers=<orbax.checkpoint._src.checkpointers.pytree_checkpointer.PyTreeCheckpointer object at 0x7f8180803a60>, item_names=None, item_handlers=None, handler_registry=None
# Configured `CheckpointManager` using deprecated legacy API. Please follow the instructions at https://orbax.readthedocs.io/en/latest/api_refactor.html to migrate.
# Deferred registration for item: "default". Adding handler `<orbax.checkpoint._src.handlers.pytree_checkpoint_handler.PyTreeCheckpointHandler object at 0x7f817bdfbf10>` for item "default" and save args `<class 'orbax.checkpoint._src.handlers.pytree_checkpoint_handler.PyTreeSaveArgs'>` and restore args `<class 'orbax.checkpoint._src.handlers.pytree_checkpoint_handler.PyTreeRestoreArgs'>` to `_handler_registry`.
# Deferred registration for item: "metrics". Adding handler `<orbax.checkpoint._src.handlers.json_checkpoint_handler.JsonCheckpointHandler object at 0x7f817be19e40>` for item "metrics" and save args `<class 'orbax.checkpoint._src.handlers.json_checkpoint_handler.JsonSaveArgs'>` and restore args `<class 'orbax.checkpoint._src.handlers.json_checkpoint_handler.JsonRestoreArgs'>` to `_handler_registry`.
# Initialized registry DefaultCheckpointHandlerRegistry({('default', <class 'orbax.checkpoint._src.handlers.pytree_checkpoint_handler.PyTreeSaveArgs'>): <orbax.checkpoint._src.handlers.pytree_checkpoint_handler.PyTreeCheckpointHandler object at 0x7f817bdfbf10>, ('default', <class 'orbax.checkpoint._src.handlers.pytree_checkpoint_handler.PyTreeRestoreArgs'>): <orbax.checkpoint._src.handlers.pytree_checkpoint_handler.PyTreeCheckpointHandler object at 0x7f817bdfbf10>, ('metrics', <class 'orbax.checkpoint._src.handlers.json_checkpoint_handler.JsonSaveArgs'>): <orbax.checkpoint._src.handlers.json_checkpoint_handler.JsonCheckpointHandler object at 0x7f817be19e40>, ('metrics', <class 'orbax.checkpoint._src.handlers.json_checkpoint_handler.JsonRestoreArgs'>): <orbax.checkpoint._src.handlers.json_checkpoint_handler.JsonCheckpointHandler object at 0x7f817be19e40>}).
# Created directory=/home/hbeyer/RL_Pendulum_Project/physics_environments/experiments/checkpoints/ff_ppo/20241219151314
# [process=0][thread=MainThread] Skipping global process sync, barrier name: CheckpointManager:create_directory
# Found 0 checkpoint steps in /home/hbeyer/RL_Pendulum_Project/physics_environments/experiments/checkpoints/ff_ppo/20241219151314
# Saving root metadata
# Creating metadata directory
# Writing root metadata
# Wrote Metadata={'format': None, 'custom': {'checkpointer_version': 1.0, 'arch': {'absolute_metric': True, 'architecture_name': 'anakin', 'evaluation_greedy': False, 'num_envs': 5120, 'num_eval_episodes': 128, 'num_evaluation': 100, 'num_updates': 12207, 'num_updates_per_eval': 122, 'seed': 42, 'total_num_envs': 5120, 'total_timesteps': 1000000000, 'update_batch_size': 1}, 'env': {'env_name': 'jumanji', 'eval_metric': 'episode_return', 'kwargs': {'params': {'_init_phyiscs_env_from_file': False, '_initialize_env_math': False, '_physics_env_init_filename': 'pendulum_obj_filename.pkl', 'cart_width': 0.25, 'dt': 0.01, 'max_cart_acceleration': 25.0, 'physics_env_params': {'constants': {'I': [0.011], 'g': 9.81, 'l': [0.3], 'm': [0.8], 'mu': [0.015], 'n': 1, 'r': [0.2]}, 'env_type': 'compound pendulum', 'save_after_init': False, 'save_filename': 'env1n_compound pendulum_obj.pkl'}, 'reward_exponent': 1.0, 't_episode': 10.0, 'track_width': 1.25, 'training_generator_type': 'DefaultGenerator'}}, 'multi_agent': False, 'observation_attribute': 'agent_inputs_global', 'scenario': {'name': 'cart_n_pendulum-v1', 'task_name': 'cart_1_pendulum'}, 'solved_return_threshold': 500.0}, 'logger': {'base_exp_path': 'results', 'checkpointing': {'load_args': {'checkpoint_uid': ''}, 'load_model': False, 'save_args': {'checkpoint_uid': None, 'keep_period': None, 'max_to_keep': 1, 'save_interval_steps': 1}, 'save_model': True}, 'kwargs': {'detailed_logging': True, 'json_path': None, 'project': None, 'tags': ['stoix'], 'upload_json_data': False}, 'use_console': True, 'use_json': False, 'use_neptune': False, 'use_tb': False, 'use_wandb': False}, 'network': {'actor_network': {'action_head': {'_target_': 'stoix.networks.heads.NormalAffineTanhDistributionHead'}, 'pre_torso': {'_target_': 'stoix.networks.torso.MLPTorso', 'activation': 'silu', 'layer_sizes': [256, 256, 256, 256], 'use_layer_norm': False}}, 'critic_network': {'critic_head': {'_target_': 'stoix.networks.heads.ScalarCriticHead'}, 'pre_torso': {'_target_': 'stoix.networks.torso.MLPTorso', 'activation': 'silu', 'layer_sizes': [256, 256, 256, 256], 'use_layer_norm': False}}}, 'num_devices': 1, 'system': {'action_dim': 1, 'action_maximum': 25.0, 'action_minimum': -25.0, 'actor_lr': 0.0003, 'clip_eps': 0.2, 'critic_lr': 0.0003, 'decay_learning_rates': False, 'ent_coef': 0.001, 'epochs': 4, 'gae_lambda': 0.95, 'gamma': 0.99, 'kl_penalty_coef': 3.0, 'max_grad_norm': 0.5, 'num_minibatches': 16, 'rollout_length': 16, 'standardize_advantages': True, 'system_name': 'ff_ppo', 'vf_coef': 1.0}}}, json={"format": null, "custom": {"checkpointer_version": 1.0, "arch": {"absolute_metric": true, "architecture_name": "anakin", "evaluation_greedy": false, "num_envs": 5120, "num_eval_episodes": 128, "num_evaluation": 100, "num_updates": 12207, "num_updates_per_eval": 122, "seed": 42, "total_num_envs": 5120, "total_timesteps": 1000000000, "update_batch_size": 1}, "env": {"env_name": "jumanji", "eval_metric": "episode_return", "kwargs": {"params": {"_init_phyiscs_env_from_file": false, "_initialize_env_math": false, "_physics_env_init_filename": "pendulum_obj_filename.pkl", "cart_width": 0.25, "dt": 0.01, "max_cart_acceleration": 25.0, "physics_env_params": {"constants": {"I": [0.011], "g": 9.81, "l": [0.3], "m": [0.8], "mu": [0.015], "n": 1, "r": [0.2]}, "env_type": "compound pendulum", "save_after_init": false, "save_filename": "env1n_compound pendulum_obj.pkl"}, "reward_exponent": 1.0, "t_episode": 10.0, "track_width": 1.25, "training_generator_type": "DefaultGenerator"}}, "multi_agent": false, "observation_attribute": "agent_inputs_global", "scenario": {"name": "cart_n_pendulum-v1", "task_name": "cart_1_pendulum"}, "solved_return_threshold": 500.0}, "logger": {"base_exp_path": "results", "checkpointing": {"load_args": {"checkpoint_uid": ""}, "load_model": false, "save_args": {"checkpoint_uid": null, "keep_period": null, "max_to_keep": 1, "save_interval_steps": 1}, "save_model": true}, "kwargs": {"detailed_logging": true, ...
# [process=0][thread=MainThread] Skipping global process sync, barrier name: CheckpointManager:save_metadata.0
# [process=0][thread=MainThread] CheckpointManager created,  primary_host=0, CheckpointManagerOptions=CheckpointManagerOptions(save_interval_steps=1, max_to_keep=1, keep_time_interval=None, keep_period=None, should_keep_fn=None, best_fn=<function Checkpointer.__init__.<locals>.<lambda> at 0x7f817be1c5e0>, best_mode='max', keep_checkpoints_without_metrics=True, step_prefix=None, step_format_fixed_length=None, step_name_format=None, create=True, cleanup_tmp_directories=False, save_on_steps=frozenset(), single_host_load_and_broadcast=False, todelete_subdir=None, enable_background_delete=False, read_only=False, enable_async_checkpointing=True, async_options=AsyncOptions(timeout_secs=600, barrier_sync_fn=None, post_finalization_callback=None), multiprocessing_options=MultiprocessingOptions(primary_host=0, active_processes=None, barrier_sync_key_prefix=None), should_save_fn=None, file_options=FileOptions(path_permission_mode=None), save_root_metadata=True, temporary_path_class=None), root_directory=/home/hbeyer/RL_Pendulum_Project/physics_environments/experiments/checkpoints/ff_ppo/20241219151314: <orbax.checkpoint.checkpoint_manager.CheckpointManager object at 0x7f817be19f00>
# MISC - Timestep: 9994240
# ACTOR - Steps per second: 297081.879 | Episode length mean: 1000.000 | Episode length std: 0.000 | Episode length min: 1000.000 | Episode length max: 1000.000 | Episode return mean: 429.837 | Episode return std: 24.394 | Episode return min: 335.044 | Episode return max: 524.843
# TRAINER - Actor loss: 0.003 | Entropy: -7.981 | Steps per second: 232.095 | Value loss: 1174.186
# EVALUATOR - Solve rate: 53.125 | Steps per second: 31692.902 | Episode length mean: 1000.000 | Episode length std: 0.000 | Episode length min: 1000.000 | Episode length max: 1000.000 | Episode return mean: 502.239 | Episode return std: 8.521 | Episode return min: 479.620 | Episode return max: 538.460
# MISC - Timestep: 19988480
# ACTOR - Steps per second: 422112.962 | Episode length mean: 1000.000 | Episode length std: 0.000 | Episode length min: 1000.000 | Episode length max: 1000.000 | Episode return mean: 492.698 | Episode return std: 9.093 | Episode return min: 436.333 | Episode return max: 546.298
# TRAINER - Actor loss: 0.001 | Entropy: -7.485 | Steps per second: 329.776 | Value loss: 937.497
# EVALUATOR - Solve rate: 46.875 | Steps per second: 67420.854 | Episode length mean: 1000.000 | Episode length std: 0.000 | Episode length min: 1000.000 | Episode length max: 1000.000 | Episode return mean: 500.854 | Episode return std: 9.291 | Episode return min: 476.770 | Episode return max: 531.123
# MISC - Timestep: 29982720
# ACTOR - Steps per second: 411151.261 | Episode length mean: 1000.000 | Episode length std: 0.000 | Episode length min: 1000.000 | Episode length max: 1000.000 | Episode return mean: 495.675 | Episode return std: 10.929 | Episode return min: 348.825 | Episode return max: 564.433
# TRAINER - Actor loss: 0.003 | Entropy: -5.358 | Steps per second: 321.212 | Value loss: 404.916
# EVALUATOR - Solve rate: 100.000 | Steps per second: 66811.810 | Episode length mean: 1000.000 | Episode length std: 0.000 | Episode length min: 1000.000 | Episode length max: 1000.000 | Episode return mean: 506.452 | Episode return std: 2.061 | Episode return min: 502.722 | Episode return max: 512.958
# MISC - Timestep: 39976960
# ACTOR - Steps per second: 412312.459 | Episode length mean: 1000.000 | Episode length std: 0.000 | Episode length min: 1000.000 | Episode length max: 1000.000 | Episode return mean: 503.759 | Episode return std: 23.017 | Episode return min: 302.766 | Episode return max: 652.326
# TRAINER - Actor loss: 0.008 | Entropy: -4.358 | Steps per second: 322.119 | Value loss: 164.758
# EVALUATOR - Solve rate: 100.000 | Steps per second: 78345.076 | Episode length mean: 1000.000 | Episode length std: 0.000 | Episode length min: 1000.000 | Episode length max: 1000.000 | Episode return mean: 503.340 | Episode return std: 0.815 | Episode return min: 501.931 | Episode return max: 506.873
# MISC - Timestep: 49971200
# ACTOR - Steps per second: 407983.246 | Episode length mean: 1000.000 | Episode length std: 0.000 | Episode length min: 1000.000 | Episode length max: 1000.000 | Episode return mean: 487.605 | Episode return std: 53.738 | Episode return min: 333.297 | Episode return max: 575.242
# TRAINER - Actor loss: 0.004 | Entropy: -4.461 | Steps per second: 318.737 | Value loss: 49.961
# EVALUATOR - Solve rate: 100.000 | Steps per second: 65552.428 | Episode length mean: 1000.000 | Episode length std: 0.000 | Episode length min: 1000.000 | Episode length max: 1000.000 | Episode return mean: 507.088 | Episode return std: 1.080 | Episode return min: 504.966 | Episode return max: 510.379
# MISC - Timestep: 59965440
# ACTOR - Steps per second: 409521.976 | Episode length mean: 1000.000 | Episode length std: 0.000 | Episode length min: 1000.000 | Episode length max: 1000.000 | Episode return mean: 511.465 | Episode return std: 32.678 | Episode return min: 257.180 | Episode return max: 585.857
# TRAINER - Actor loss: 0.011 | Entropy: -3.132 | Steps per second: 319.939 | Value loss: 27.999
# EVALUATOR - Solve rate: 95.312 | Steps per second: 78094.517 | Episode length mean: 1000.000 | Episode length std: 0.000 | Episode length min: 1000.000 | Episode length max: 1000.000 | Episode return mean: 544.982 | Episode return std: 44.677 | Episode return min: 355.777 | Episode return max: 651.058
# MISC - Timestep: 69959680
# ACTOR - Steps per second: 413040.221 | Episode length mean: 1000.000 | Episode length std: 0.000 | Episode length min: 1000.000 | Episode length max: 1000.000 | Episode return mean: 519.006 | Episode return std: 72.258 | Episode return min: 292.314 | Episode return max: 722.828
# TRAINER - Actor loss: 0.006 | Entropy: -1.054 | Steps per second: 322.688 | Value loss: 20.586
# EVALUATOR - Solve rate: 100.000 | Steps per second: 79701.005 | Episode length mean: 1000.000 | Episode length std: 0.000 | Episode length min: 1000.000 | Episode length max: 1000.000 | Episode return mean: 537.990 | Episode return std: 12.263 | Episode return min: 519.335 | Episode return max: 576.183
# MISC - Timestep: 79953920
# ACTOR - Steps per second: 404978.075 | Episode length mean: 1000.000 | Episode length std: 0.000 | Episode length min: 1000.000 | Episode length max: 1000.000 | Episode return mean: 497.902 | Episode return std: 81.788 | Episode return min: 350.625 | Episode return max: 947.414
# TRAINER - Actor loss: 0.020 | Entropy: -0.263 | Steps per second: 316.389 | Value loss: 5.681
# EVALUATOR - Solve rate: 100.000 | Steps per second: 67038.532 | Episode length mean: 1000.000 | Episode length std: 0.000 | Episode length min: 1000.000 | Episode length max: 1000.000 | Episode return mean: 966.780 | Episode return std: 1.963 | Episode return min: 959.506 | Episode return max: 970.434
# MISC - Timestep: 89948160
# ACTOR - Steps per second: 400161.619 | Episode length mean: 1000.000 | Episode length std: 0.000 | Episode length min: 1000.000 | Episode length max: 1000.000 | Episode return mean: 946.966 | Episode return std: 44.225 | Episode return min: 324.848 | Episode return max: 970.788
# TRAINER - Actor loss: 0.016 | Entropy: 1.387 | Steps per second: 312.626 | Value loss: 20.658
# EVALUATOR - Solve rate: 100.000 | Steps per second: 79141.603 | Episode length mean: 1000.000 | Episode length std: 0.000 | Episode length min: 1000.000 | Episode length max: 1000.000 | Episode return mean: 965.632 | Episode return std: 2.283 | Episode return min: 958.577 | Episode return max: 970.000
# MISC - Timestep: 99942400
# ACTOR - Steps per second: 402284.878 | Episode length mean: 1000.000 | Episode length std: 0.000 | Episode length min: 1000.000 | Episode length max: 1000.000 | Episode return mean: 969.413 | Episode return std: 11.461 | Episode return min: 436.564 | Episode return max: 976.359
# TRAINER - Actor loss: 0.002 | Entropy: 2.145 | Steps per second: 314.285 | Value loss: 26.156
# EVALUATOR - Solve rate: 100.000 | Steps per second: 68807.709 | Episode length mean: 1000.000 | Episode length std: 0.000 | Episode length min: 1000.000 | Episode length max: 1000.000 | Episode return mean: 975.291 | Episode return std: 1.033 | Episode return min: 972.524 | Episode return max: 976.957
# MISC - Timestep: 109936640
# ACTOR - Steps per second: 397862.737 | Episode length mean: 1000.000 | Episode length std: 0.000 | Episode length min: 1000.000 | Episode length max: 1000.000 | Episode return mean: 974.927 | Episode return std: 1.397 | Episode return min: 963.575 | Episode return max: 977.312
# TRAINER - Actor loss: 0.003 | Entropy: 2.267 | Steps per second: 310.830 | Value loss: 27.178
# EVALUATOR - Solve rate: 100.000 | Steps per second: 76459.791 | Episode length mean: 1000.000 | Episode length std: 0.000 | Episode length min: 1000.000 | Episode length max: 1000.000 | Episode return mean: 974.369 | Episode return std: 1.122 | Episode return min: 971.825 | Episode return max: 975.814
# MISC - Timestep: 119930880
# ACTOR - Steps per second: 400048.045 | Episode length mean: 1000.000 | Episode length std: 0.000 | Episode length min: 1000.000 | Episode length max: 1000.000 | Episode return mean: 974.251 | Episode return std: 1.118 | Episode return min: 969.797 | Episode return max: 976.105
# TRAINER - Actor loss: 0.005 | Entropy: 2.138 | Steps per second: 312.538 | Value loss: 28.047
# EVALUATOR - Solve rate: 100.000 | Steps per second: 78010.352 | Episode length mean: 1000.000 | Episode length std: 0.000 | Episode length min: 1000.000 | Episode length max: 1000.000 | Episode return mean: 974.905 | Episode return std: 1.001 | Episode return min: 972.223 | Episode return max: 976.245
# MISC - Timestep: 129925120
# ACTOR - Steps per second: 395729.026 | Episode length mean: 1000.000 | Episode length std: 0.000 | Episode length min: 1000.000 | Episode length max: 1000.000 | Episode return mean: 974.304 | Episode return std: 1.927 | Episode return min: 912.983 | Episode return max: 976.784
# TRAINER - Actor loss: 0.008 | Entropy: 2.060 | Steps per second: 309.163 | Value loss: 29.837
# EVALUATOR - Solve rate: 100.000 | Steps per second: 68847.699 | Episode length mean: 1000.000 | Episode length std: 0.000 | Episode length min: 1000.000 | Episode length max: 1000.000 | Episode return mean: 972.285 | Episode return std: 1.889 | Episode return min: 965.872 | Episode return max: 975.708
# MISC - Timestep: 139919360
# ACTOR - Steps per second: 392520.539 | Episode length mean: 1000.000 | Episode length std: 0.000 | Episode length min: 1000.000 | Episode length max: 1000.000 | Episode return mean: 972.398 | Episode return std: 5.908 | Episode return min: 548.771 | Episode return max: 976.280
# TRAINER - Actor loss: 0.006 | Entropy: 1.980 | Steps per second: 306.657 | Value loss: 29.433
# EVALUATOR - Solve rate: 100.000 | Steps per second: 78703.942 | Episode length mean: 1000.000 | Episode length std: 0.000 | Episode length min: 1000.000 | Episode length max: 1000.000 | Episode return mean: 974.437 | Episode return std: 1.314 | Episode return min: 968.936 | Episode return max: 976.197
# MISC - Timestep: 149913600
# ACTOR - Steps per second: 390782.402 | Episode length mean: 1000.000 | Episode length std: 0.000 | Episode length min: 1000.000 | Episode length max: 1000.000 | Episode return mean: 974.990 | Episode return std: 1.163 | Episode return min: 920.888 | Episode return max: 976.433
# TRAINER - Actor loss: 0.005 | Entropy: 2.064 | Steps per second: 305.299 | Value loss: 30.222
# EVALUATOR - Solve rate: 100.000 | Steps per second: 68863.188 | Episode length mean: 1000.000 | Episode length std: 0.000 | Episode length min: 1000.000 | Episode length max: 1000.000 | Episode return mean: 975.445 | Episode return std: 0.586 | Episode return min: 973.043 | Episode return max: 976.099
# MISC - Timestep: 159907840
# ACTOR - Steps per second: 386989.266 | Episode length mean: 1000.000 | Episode length std: 0.000 | Episode length min: 1000.000 | Episode length max: 1000.000 | Episode return mean: 975.311 | Episode return std: 1.099 | Episode return min: 955.868 | Episode return max: 976.565
# TRAINER - Actor loss: 0.010 | Entropy: 1.839 | Steps per second: 302.335 | Value loss: 30.196
# EVALUATOR - Solve rate: 100.000 | Steps per second: 90107.148 | Episode length mean: 1000.000 | Episode length std: 0.000 | Episode length min: 1000.000 | Episode length max: 1000.000 | Episode return mean: 975.967 | Episode return std: 0.675 | Episode return min: 973.132 | Episode return max: 976.745
# MISC - Timestep: 169902080
# ACTOR - Steps per second: 390470.303 | Episode length mean: 1000.000 | Episode length std: 0.000 | Episode length min: 1000.000 | Episode length max: 1000.000 | Episode return mean: 976.278 | Episode return std: 0.795 | Episode return min: 970.840 | Episode return max: 977.039
# TRAINER - Actor loss: 0.011 | Entropy: 1.439 | Steps per second: 305.055 | Value loss: 30.787
# EVALUATOR - Solve rate: 100.000 | Steps per second: 69126.511 | Episode length mean: 1000.000 | Episode length std: 0.000 | Episode length min: 1000.000 | Episode length max: 1000.000 | Episode return mean: 975.296 | Episode return std: 0.568 | Episode return min: 971.000 | Episode return max: 975.802
# MISC - Timestep: 179896320
# ACTOR - Steps per second: 388982.331 | Episode length mean: 1000.000 | Episode length std: 0.000 | Episode length min: 1000.000 | Episode length max: 1000.000 | Episode return mean: 976.042 | Episode return std: 0.465 | Episode return min: 968.335 | Episode return max: 976.805
# TRAINER - Actor loss: 0.009 | Entropy: 1.367 | Steps per second: 303.892 | Value loss: 30.675
# EVALUATOR - Solve rate: 100.000 | Steps per second: 89643.235 | Episode length mean: 1000.000 | Episode length std: 0.000 | Episode length min: 1000.000 | Episode length max: 1000.000 | Episode return mean: 977.136 | Episode return std: 0.610 | Episode return min: 975.110 | Episode return max: 977.465
# MISC - Timestep: 189890560
# ACTOR - Steps per second: 388268.740 | Episode length mean: 1000.000 | Episode length std: 0.000 | Episode length min: 1000.000 | Episode length max: 1000.000 | Episode return mean: 976.927 | Episode return std: 0.791 | Episode return min: 971.388 | Episode return max: 977.536
# TRAINER - Actor loss: 0.008 | Entropy: 1.211 | Steps per second: 303.335 | Value loss: 31.675
# EVALUATOR - Solve rate: 100.000 | Steps per second: 78513.545 | Episode length mean: 1000.000 | Episode length std: 0.000 | Episode length min: 1000.000 | Episode length max: 1000.000 | Episode return mean: 977.054 | Episode return std: 0.477 | Episode return min: 974.930 | Episode return max: 977.403
# MISC - Timestep: 199884800
# ACTOR - Steps per second: 381917.443 | Episode length mean: 1000.000 | Episode length std: 0.000 | Episode length min: 1000.000 | Episode length max: 1000.000 | Episode return mean: 730.792 | Episode return std: 267.503 | Episode return min: 331.249 | Episode return max: 977.383
# TRAINER - Actor loss: 0.005 | Entropy: -3.268 | Steps per second: 298.373 | Value loss: 124.942
# EVALUATOR - Solve rate: 100.000 | Steps per second: 68126.746 | Episode length mean: 1000.000 | Episode length std: 0.000 | Episode length min: 1000.000 | Episode length max: 1000.000 | Episode return mean: 970.998 | Episode return std: 1.335 | Episode return min: 966.407 | Episode return max: 973.068
# MISC - Timestep: 209879040
# ACTOR - Steps per second: 386895.671 | Episode length mean: 1000.000 | Episode length std: 0.000 | Episode length min: 1000.000 | Episode length max: 1000.000 | Episode return mean: 970.481 | Episode return std: 1.841 | Episode return min: 916.005 | Episode return max: 973.940
# TRAINER - Actor loss: 0.005 | Entropy: 1.333 | Steps per second: 302.262 | Value loss: 17.631
# EVALUATOR - Solve rate: 100.000 | Steps per second: 75904.347 | Episode length mean: 1000.000 | Episode length std: 0.000 | Episode length min: 1000.000 | Episode length max: 1000.000 | Episode return mean: 973.502 | Episode return std: 0.781 | Episode return min: 970.795 | Episode return max: 974.676
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/RL_Pendulum_Project/Stoix/stoix/systems/ppo/anakin/ff_ppo_continuous.py:601
#     597     return eval_performance
#     600 if __name__ == "__main__":
# --> 601     hydra_entry_point()
#
# File ~/anaconda3/envs/python_3.10.8/lib/python3.10/site-packages/hydra/main.py:94, in main.<locals>.main_decorator.<locals>.decorated_main(cfg_passthrough)
#      90     _flush_loggers()
#      91 else:
#      92     # no return value from run_hydra() as it may sometime actually run the task_function
#      93     # multiple times (--multirun)
# ---> 94     _run_hydra(
#      95         args=args,
#      96         args_parser=args_parser,
#      97         task_function=task_function,
#      98         config_path=config_path,
#      99         config_name=config_name,
#     100     )
#
# File ~/anaconda3/envs/python_3.10.8/lib/python3.10/site-packages/hydra/_internal/utils.py:394, in _run_hydra(args, args_parser, task_function, config_path, config_name, caller_stack_depth)
#     392 if args.run or args.multirun:
#     393     run_mode = hydra.get_mode(config_name=config_name, overrides=overrides)
# --> 394     _run_app(
#     395         run=args.run,
#     396         multirun=args.multirun,
#     397         mode=run_mode,
#     398         hydra=hydra,
#     399         config_name=config_name,
#     400         task_function=task_function,
#     401         overrides=overrides,
#     402     )
#     403 elif args.cfg:
#     404     run_and_report(
#     405         lambda: hydra.show_cfg(
#     406             config_name=config_name,
#    (...)
#     411         )
#     412     )
#
# File ~/anaconda3/envs/python_3.10.8/lib/python3.10/site-packages/hydra/_internal/utils.py:457, in _run_app(run, multirun, mode, hydra, config_name, task_function, overrides)
#     454         overrides.extend(["hydra.mode=MULTIRUN"])
#     456 if mode == RunMode.RUN:
# --> 457     run_and_report(
#     458         lambda: hydra.run(
#     459             config_name=config_name,
#     460             task_function=task_function,
#     461             overrides=overrides,
#     462         )
#     463     )
#     464 else:
#     465     run_and_report(
#     466         lambda: hydra.multirun(
#     467             config_name=config_name,
#    (...)
#     470         )
#     471     )
#
# File ~/anaconda3/envs/python_3.10.8/lib/python3.10/site-packages/hydra/_internal/utils.py:220, in run_and_report(func)
#     218 def run_and_report(func: Any) -> Any:
#     219     try:
# --> 220         return func()
#     221     except Exception as ex:
#     222         if _is_env_set("HYDRA_FULL_ERROR") or is_under_debugger():
#
# File ~/anaconda3/envs/python_3.10.8/lib/python3.10/site-packages/hydra/_internal/utils.py:458, in _run_app.<locals>.<lambda>()
#     454         overrides.extend(["hydra.mode=MULTIRUN"])
#     456 if mode == RunMode.RUN:
#     457     run_and_report(
# --> 458         lambda: hydra.run(
#     459             config_name=config_name,
#     460             task_function=task_function,
#     461             overrides=overrides,
#     462         )
#     463     )
#     464 else:
#     465     run_and_report(
#     466         lambda: hydra.multirun(
#     467             config_name=config_name,
#    (...)
#     470         )
#     471     )
#
# File ~/anaconda3/envs/python_3.10.8/lib/python3.10/site-packages/hydra/_internal/hydra.py:119, in Hydra.run(self, config_name, task_function, overrides, with_log_configuration)
#     116 callbacks = Callbacks(cfg)
#     117 callbacks.on_run_start(config=cfg, config_name=config_name)
# --> 119 ret = run_job(
#     120     hydra_context=HydraContext(
#     121         config_loader=self.config_loader, callbacks=callbacks
#     122     ),
#     123     task_function=task_function,
#     124     config=cfg,
#     125     job_dir_key="hydra.run.dir",
#     126     job_subdir_key=None,
#     127     configure_logging=with_log_configuration,
#     128 )
#     129 callbacks.on_run_end(config=cfg, config_name=config_name, job_return=ret)
#     131 # access the result to trigger an exception in case the job failed.
#
# File ~/anaconda3/envs/python_3.10.8/lib/python3.10/site-packages/hydra/core/utils.py:186, in run_job(task_function, config, job_dir_key, job_subdir_key, hydra_context, configure_logging)
#     184 callbacks.on_job_start(config=config, task_function=task_function)
#     185 try:
# --> 186     ret.return_value = task_function(task_cfg)
#     187     ret.status = JobStatus.COMPLETED
#     188 except Exception as e:
#
# File ~/RL_Pendulum_Project/Stoix/stoix/systems/ppo/anakin/ff_ppo_continuous.py:595, in hydra_entry_point(cfg)
#     592 cfg.env.kwargs.params = hydra.utils.instantiate(cfg.env.kwargs.params) # added line to instantiate _target_ objects in config; hbeyer
#     594 # Run experiment.
# --> 595 eval_performance = run_experiment(cfg)
#     596 print(f"{Fore.CYAN}{Style.BRIGHT}PPO experiment completed{Style.RESET_ALL}")
#     597 return eval_performance
#
# File ~/RL_Pendulum_Project/Stoix/stoix/systems/ppo/anakin/ff_ppo_continuous.py:500, in run_experiment(_config)
#     497 for eval_step in range(config.arch.num_evaluation):
#     498     # Train.
#     499     start_time = time.time()
# --> 500     learner_output = learn(learner_state)
#     501     jax.block_until_ready(learner_output)
#     502     # Log the results of the training.
#
# File <string>:1, in <lambda>(_cls, actor_params, critic_params)
#
# KeyboardInterrupt:
